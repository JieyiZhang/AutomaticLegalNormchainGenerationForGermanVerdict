# %%
from xml.dom.minidom import parse, parseString
import xml.etree.ElementTree as ET
import re
import numpy as np
import os

# %%
def get_normchain(doc):
# Return all legal norms in the norm chain in node "NORM" in each verdict documentation
    norm_chain = []
    for node in doc.getElementsByTagName('NORM'):
        for t in node.childNodes:
            print(t.nodeValue)
            norm_chain.append(t.nodeValue)
    return norm_chain

def preprocess_extraction(ext):
    processed=[]
    for e in ext:
        e = e[0]
        if ',' in e:
            print(e)
            words = e.split()
            indices = [i-1 for i, x in enumerate(words) if x == "Abs."]
            if len(indices)==1:
                words = re.split(' |, ', e)
                for j in range(2,len(words)-1):
                    l=' '.join(list( words[i] for i in [0, 1, j, -1] ))
                    processed.append(l)
            if len(indices)>1:
                for i in range(len(indices)):
                    if i!=len(indices)-1:
                        string = ' '.join(words[indices[i]:indices[i+1]])
                        string = string[:-1]+' '+words[-1]
                        processed.append(string)
                    else:
                        processed.append(' '.join(words[indices[i]:len(words)]))
        else:
            processed.append(e)
    return processed

def get_normsAll(tree):
# Return all norms annotated in relevant sections (except NORM and NORMENKETTE) in 
# each verdict documentation
    root = tree.getroot()
    
    sections = ['SCHLAGWORT', 'ANMERKUNG',
                'UNTERSCHLAGWORT', 'ENTSCHEIDUNGSFORMEL','TATBESTAND', 'NACHGEHEND', 'GRUENDE']
    
    section_weights = {'SCHLAGWORT':1, 'ANMERKUNG':1,
            'UNTERSCHLAGWORT':1, 'ENTSCHEIDUNGSFORMEL':1,'TATBESTAND':1, 'NACHGEHEND':1, 'GRUENDE':1}
    
    norms = {}
    
    pattern = '§\s(\d+[a-zA-ZäüöÄÜÖß]*[\sFall|Abs.|Satz|Nr.\s\d+[,\s\d+]*]*\s([a-z]+ )*[A-Z][a-zA-ZäüöÄÜÖß]+)'    
#     pattern = '§\s(\d+[a-zA-ZäüöÄÜÖß]*[\sAbs.|Satz|Nr.\s\d+[,\s\d+]*]*\s[a-zA-ZäüöÄÜÖß]+)'
    
    for section in sections:
        for node in root.iter(section):
            for i in node.iter():
                if i.tag != 'VERWEIS-GS':
                    string = i.text
                    try:
                        ext = re.findall(pattern, string)
                        processed = preprocess_extraction(ext)
                        for e in processed:
                            book = re.findall('(\w+)',e)[-1]
                            art = re.findall('(\d+)',e)[0]
                            norm = book + ' ' + art
                            if norm not in norms:
                                norms[norm] = {}
                            art_abs = re.findall('(\d+\w+\sAbs.\s\d+)',e)
                            if art_abs==[]:
                                if norm in norms[norm]:
                                    norms[norm][norm] += section_weights[section]
                                else:
                                    norms[norm][norm] = section_weights[section]
                            else:
                                for s in art_abs:
                                    name = book + ' '  + s
                                    if name in norms[norm]:
                                        norms[norm][name] += section_weights[section]
                                    else:
                                        norms[norm][name] = section_weights[section]                                
                    except:
                        pass
                else:
                    attr = i.attrib
                    string = i.text
                    book = re.findall('(\w+)',string)[-1]
                    norm = attr['PUBKUERZEL']+' ' + attr['NORM']
                    if norm not in norms:
                        norms[norm] = {}
                    art_abs = re.findall('(\d+\w+\sAbs.\s\d+)',string)                     
                    if art_abs==[]:
                        if norm in norms[norm]:
                            norms[norm][norm] += section_weights[section] 
                        else:
                            norms[norm][norm] = section_weights[section] 
                    else:
                        for s in art_abs:
                            name = attr['PUBKUERZEL'] + ' '  + s
                            if name in norms[norm]:
                                norms[norm][name] += section_weights[section] 
                            else:
                                norms[norm][name] = section_weights[section] 
                if i.tail is not None:
                    string = i.tail
                    try:
                        ext = re.findall(pattern, string)
                        processed=preprocess_extraction(ext)
                        for e in processed:
                            book = re.findall('(\w+)',e)[-1]
                            art = re.findall('(\d+)',e)[0]
                            norm = book + ' ' + art
                            if norm not in norms:
                                norms[norm] = {}
                            art_abs = re.findall('(\d+\w+\sAbs.\s\d+)',e)
                            if art_abs==[]:
                                if norm in norms[norm]:
                                    norms[norm][norm] += section_weights[section]
                                else:
                                    norms[norm][norm] = section_weights[section]
                            else:
                                for s in art_abs:
                                    name = book + ' '  + s
                                    if name in norms[norm]:
                                        norms[norm][name] += section_weights[section]
                                    else:
                                        norms[norm][name] = section_weights[section]                              
                    except:
                        pass
                    
    return norms


def generate_normchain(norms, threshold = 2):
    chain = []
    
    for (key, value) in norms.items():
        if len(value) == 1:
            for (key_2, value_2) in value.items():
                if value_2 > threshold:
                    key_2 = key_2.replace(u'\xa0', u' ')
                    chain.append(key_2)
        else:
            append_key = True
            candidates = {}
            for (key_2, value_2) in value.items():
                if (value_2 > threshold) & (key_2 != key):
                    key_2 = key_2.replace(u'\xa0', u' ')
                    candidates[key_2] = value_2
                    append_key = False
            if append_key:
                key = key.replace(u'\xa0', u' ')
                chain.append(key)
            else:
                name = max(candidates, key=candidates.get)
                name = name.replace(u'\xa0', u' ')
                chain.append(name)
    return chain


def extr2mat(arr):
# This function extract the [info, value] pairs from the extracted norms. 
# E.g. norm string 'ZPO 139 Abs. 1' and 'ZPO 522' for a docuumentation is extracted as 
# a 3-D matrix [[[ZPO, Abs],[139, 1]],[['ZPO'],[522]]]
    extraction = []
    for n in arr:
        s = re.findall('(\D[a-zA-ZäüöÄÜÖß.]+\d*[a-zA-ZäüöÄÜÖß.]*[-]*[a-zA-ZäüöÄÜÖß.]*[\\]*[a-zA-ZäüöÄÜÖß.]*)\s',n)
        s = [x.strip(' ') for x in s]
        s = [x for x in s if len(x) > 1]       
        remove = ['Art.', 'a.F.', 'i.V.m.', 'Anh.', 'zu', 'BW', 'i.d.F.','und', 'n.F.',
                  'BEL', 'THA', 'BRA', 'FRA', 'CHE', 'Baugewerbe', 'Bund', 'Abschn.',
                  'BT-K', 'NRW', 'Berlin', 'iVm.', 'NW', 'XII', 'II', 'Schl.-H.', 'MV',
                  'Bln', 'RhPf', 'RP', '-H','Tageszeitungen',  'Flugsicherung', 'ATZ', 'DTAG',
                  'DTTS', 'DRK', 'SH', 'UmBw', 'BKK', '(Zusatzabkommen',  'Einzelhandel','Sicherheit',
                 'Bayern',  'dänischer', 'ATZ-TgRV', 'Bühne', 'BT-BBiG', 'Brandenburg', 'AWO','PV',
                 '/Lackierer', 'Th','Art','nF','Baden-Württemberg','(jetzt', 'III','u.', 'analog','VI',
                 'des','StVergAbG','JStG', 'AG','BeitrRLUmsG', 'd.', 'Rheinland-Pfalz','InfoV','Anhang','f.',
                 'Hamburger', 'StSenkG','DDR', 'BR','IV','Abkommen', 'mehr', 'Bbg','a.2']
        if len(s)>0:
            s = [x for x in s if x not in remove]
            if len(s)>1:
                if s[0]==s[1]:
                    s.pop(1)
            d = re.findall('\s(\d+\w*)',n)
            if (len(s)>0) & (len(d)>0):
                print(d)
                extraction.append([s,d])
    return extraction

# Calculate the matching score
def compute_score(norm_mat, generate_mat):
# Computed a matching score based on the number of TRUE and FALSE matching flags
    flags =[]
    for e in norm_mat:
        print(e, 'is one legal norm in the label.')
        if len(e[0])>len(e[1])+1:
            # There are some norms have name consist of several words
            # Skip calculating scores for these ones
            continue
        if (len(e[1])==1) & (len(e[0])>1):
            # There are some norms in annotation with Absatz number but without artikle number
            continue
        book = e[0][0]
        art = e[1][0]
        book_flag = False
        for i in generate_mat:
            if i[0][0]==book:
                book_flag = True
        flags.append([book_flag])
    flags=np.array(flags)
    if len(np.argwhere(flags==True))+len(np.argwhere(flags==False))>0:
        score = len(np.argwhere(flags==True))/(len(np.argwhere(flags==True))+len(np.argwhere(flags==False)))
    else:
        score = -1
    return score

# Calculate the matching score
def compute_precision_score(norm_mat, generate_mat):
# Computed a matching score based on the number of TRUE and FALSE matching flags
    flags =[]
    for e in generate_mat:
        print(e, 'is one legal norm in the label.')
        if len(e[0])>len(e[1])+1:
            # There are some norms have name consist of several words
            # Skip calculating scores for these ones
            continue
        if (len(e[1])==1) & (len(e[0])>1):
            # There are some norms in annotation with Absatz number but without artikle number
            continue
        book = e[0][0]
        art = e[1][0]
        book_flag = False
        for i in norm_mat:
            if i[0][0]==book:
                book_flag = True
        flags.append([book_flag])
    flags=np.array(flags)
    if len(np.argwhere(flags==True))+len(np.argwhere(flags==False))>0:
        score = len(np.argwhere(flags==True))/(len(np.argwhere(flags==True))+len(np.argwhere(flags==False)))
    else:
        score = -1
    return score

# %%
def compare_length(norm_mat, generate_mat):
# Compare the length of label normchain and generated normchain
    if len(norm_mat)>0:
        score = abs(len(norm_mat)-len(generate_mat))/len(norm_mat)
    else:
        score = -1
    return score

# %%
file_names = []
file_accuracy_scores = []
file_precision_scores = []
length_score = []

count = 0


# Constant value
for root, directories, files in os.walk("/Users/jieyizhang/Desktop/Master_Thesis/labelled_files", topdown=True):
    for xml_filename in files:
        if xml_filename[-4:].lower() == ".xml":
            count = count +1
            print(count/32893)
            filename = root + '/' + xml_filename
            print(filename)
            doc = parse(filename)
            tree = ET.parse(filename)
            label = get_normchain(doc)
            if len(label)>0:
                label_mat = extr2mat(label)
                try:
                    norms = get_normsAll(tree)
                    generated_chain = generate_normchain(norms)
                except:
                    print("This file has label ", label)
                    print("But something is missing or wrong within the text.")
                    continue
                generate_mat = extr2mat(generated_chain)
                accuracy_score = compute_score(label_mat, generate_mat)
                precision_score = compute_precision_score(label_mat, generate_mat)
                length_score.append(compare_length(label_mat, generate_mat))
                file_names.append(filename)
                file_precision_scores.append(precision_score)
                file_accuracy_scores.append(accuracy_score)
# Out:
# 3.040160520475481e-05
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_011283_2012_KW15.xml
# MarkenG § 14 Abs. 2 Nr. 1
# MarkenG § 14 Abs. 2 Nr. 2
# MarkenG § 14 Abs. 2 Nr. 3
# Brüssel-I-VO Art. 5 Nr. 3
# ['14', '2', '1']
# ['14', '2', '2']
# ['14', '2', '3']
# ['5', '3']
# This file has label  ['MarkenG § 14 Abs. 2 Nr. 1', 'MarkenG § 14 Abs. 2 Nr. 2', 'MarkenG § 14 Abs. 2 Nr. 3', 'Brüssel-I-VO Art. 5 Nr. 3']
# But something is missing or wrong within the text.
# 6.080321040950962e-05
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_009372_2010_KW20.xml
# MarkenG § 8 Abs. 1
# MarkenG § 8 Abs. 2 Nr. 1
# ['8', '1']
# ['8', '2', '1']
# ['8']
# [['MarkenG', 'Abs.'], ['8', '1']] is one legal norm in the label.
# [['MarkenG', 'Abs.', 'Nr.'], ['8', '2', '1']] is one legal norm in the label.
# [['MarkenG'], ['8']] is one legal norm in the label.
# 9.120481561426443e-05
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/3Ko402411.xml
# RVG 15a Abs. 1
# RVG 15a Abs. 2
# RVG 45 Abs. 1
# RVG 55 Abs. 5
# RVG 58
# VV RVG Nr. 2300
# VV RVG Nr. 3100
# ['15a', '1']
# ['15a', '2']
# ['45', '1']
# ['55', '5']
# ['58']
# ['2300']
# ['3100']
# ['45']
# ['2']
# ['15a', '1']
# ['55', '5']
# [['RVG', 'Abs.'], ['15a', '1']] is one legal norm in the label.
# [['RVG', 'Abs.'], ['15a', '2']] is one legal norm in the label.
# [['RVG', 'Abs.'], ['45', '1']] is one legal norm in the label.
# [['RVG', 'Abs.'], ['55', '5']] is one legal norm in the label.
# [['RVG'], ['58']] is one legal norm in the label.
# [['VV', 'RVG', 'Nr.'], ['2300']] is one legal norm in the label.
# [['VV', 'RVG', 'Nr.'], ['3100']] is one legal norm in the label.
# [['RVG'], ['45']] is one legal norm in the label.
# [['RVG'], ['2']] is one legal norm in the label.
# [['RVG', 'Abs.'], ['15a', '1']] is one legal norm in the label.
# [['RVG', 'Abs.'], ['55', '5']] is one legal norm in the label.
# 0.00012160642081901924
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/10TaBV7109.xml
# BetrVG 99
# BetrVG 101
# ['99']
# ['101']
# ['99', '1']
# ['101']
# ['92']
# [['BetrVG'], ['99']] is one legal norm in the label.
# [['BetrVG'], ['101']] is one legal norm in the label.
# [['BetrVG', 'Abs.'], ['99', '1']] is one legal norm in the label.
# [['BetrVG'], ['101']] is one legal norm in the label.
# [['ArbGG'], ['92']] is one legal norm in the label.
# 0.00015200802602377406
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/2K12512.xml
# UStG 14 Abs. 4 Nr. 2
# UStG 15
# Abs. 1 Nr. 1 Satz 1
# MwStSystRL
# Art. 226 Nr. 3
# RL 388/77/EWG Art. 22 Abs. 3 Buchst.
# b 6
# ['14', '4', '2']
# ['15', '1', '1', '1']
# ['226', '3']
# ['388', '22', '3', '6']
# ['15', '1']
# ['14', '4']
# ['16']
# [['UStG', 'Abs.', 'Nr.'], ['14', '4', '2']] is one legal norm in the label.
# [['UStG', '\nAbs.', 'Nr.', 'Satz'], ['15', '1', '1', '1']] is one legal norm in the label.
# [['MwStSystRL', 'Nr.'], ['226', '3']] is one legal norm in the label.
# [['RL', '/EWG', 'Abs.', 'Buchst.'], ['388', '22', '3', '6']] is one legal norm in the label.
# [['UStG', 'Abs.'], ['15', '1']] is one legal norm in the label.
# [['UStG', 'Abs.'], ['14', '4']] is one legal norm in the label.
# [['UStG'], ['16']] is one legal norm in the label.
# 0.00018240963122852886
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/1k17162009.xml
# EStG 10d
# AO 171 Abs. 10
# ['10d']
# ['171', '10']
# ['171', '10']
# ['10d']
# ['172']
# ['143']
# [['EStG'], ['10d']] is one legal norm in the label.
# [['AO', 'Abs.'], ['171', '10']] is one legal norm in the label.
# [['AO', 'Abs.'], ['171', '10']] is one legal norm in the label.
# [['EStG'], ['10d']] is one legal norm in the label.
# [['AO'], ['172']] is one legal norm in the label.
# [['FGO'], ['143']] is one legal norm in the label.
# 0.00021281123643328368
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-HM_083313.xml
# BGB § 745 Abs. 2
# BGB § 1472 Abs. 3 Hs. 1
# BGB § 1473 Abs. 1
# BGB § 1455 Nr. 6
# BGB § 1420
# BGB § 1360
# BGB § 1361
# BGB § 1476 Abs. 2
# BGB § 1467 Abs. 1
# BGB § 1468
# ['745', '2']
# ['1472', '3', '1']
# ['1473', '1']
# ['1455', '6']
# ['1420']
# ['1360']
# ['1361']
# ['1476', '2']
# ['1467', '1']
# ['1468']
# 1472, Rn
# 260, Rn
# 1417, Rn
# 1471, Rn
# 1476, Rn
# ['745', '2']
# ['1472', '3']
# ['1473', '1']
# [['BGB', 'Abs.'], ['745', '2']] is one legal norm in the label.
# [['BGB', 'Abs.', 'Hs.'], ['1472', '3', '1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['1473', '1']] is one legal norm in the label.
# [['BGB', 'Nr.'], ['1455', '6']] is one legal norm in the label.
# [['BGB'], ['1420']] is one legal norm in the label.
# [['BGB'], ['1360']] is one legal norm in the label.
# [['BGB'], ['1361']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['1476', '2']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['1467', '1']] is one legal norm in the label.
# [['BGB'], ['1468']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['745', '2']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['1472', '3']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['1473', '1']] is one legal norm in the label.
# 0.00024321284163803848
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/4k38707.xml
# ZK Art. 70
# ZK Art. 71
# VO (EG) Nr. 765/2002 Art. 1 Abs. 1 lit. c)
# VO (EG) Nr. 765/2002 Art. 2 Abs. 1
# VO
# (EG) Nr. 765/2002 Art. 5
# ['70']
# ['71']
# ['765', '1', '1']
# ['765', '2', '1']
# ['765', '5']
# This file has label  ['ZK Art. 70', 'ZK Art. 71', 'VO (EG) Nr. 765/2002 Art. 1 Abs. 1 lit. c)', 'VO (EG) Nr. 765/2002 Art. 2 Abs. 1', 'VO\n(EG) Nr. 765/2002 Art. 5']
# But something is missing or wrong within the text.
# 0.0002736144468427933
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-SH_078870.xml
# BGB § 666
# BGB § 667
# BGB § 812
# BGB § 1922
# BGB § 2039
# ['666']
# ['667']
# ['812']
# ['1922']
# ['2039']
# ['662']
# ['667']
# ['1922']
# ['662']
# ['666']
# [['BGB'], ['666']] is one legal norm in the label.
# [['BGB'], ['667']] is one legal norm in the label.
# [['BGB'], ['812']] is one legal norm in the label.
# [['BGB'], ['1922']] is one legal norm in the label.
# [['BGB'], ['2039']] is one legal norm in the label.
# [['BGB'], ['662']] is one legal norm in the label.
# [['BGB'], ['667']] is one legal norm in the label.
# [['BGB'], ['1922']] is one legal norm in the label.
# [['Rz'], ['662']] is one legal norm in the label.
# [['BGB'], ['666']] is one legal norm in the label.
# 0.0003040160520475481
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/VB7809.xml
# FGO 116 Abs 3 Satz 3
# FGO 76 Abs 1 Satz 4
# AO 90 Abs 2
# StPO 100a
# FGO 115 Abs 2 Nr 3
# ['116', '3', '3']
# ['76', '1', '4']
# ['90', '2']
# ['100a']
# ['115', '2', '3']
# ['115', '2']
# [['FGO', 'Abs', 'Satz'], ['116', '3', '3']] is one legal norm in the label.
# [['FGO', 'Abs', 'Satz'], ['76', '1', '4']] is one legal norm in the label.
# [['AO', 'Abs'], ['90', '2']] is one legal norm in the label.
# [['StPO'], ['100a']] is one legal norm in the label.
# [['FGO', 'Abs', 'Nr'], ['115', '2', '3']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['115', '2']] is one legal norm in the label.
# 0.0003344176572523029
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-BR_081337.xml
# ZPO § 128 Absatz 1
# BKleingG § 9 Abs. 1 Nr. 5
# BKleingG § 11
# ['128', '1']
# ['9', '1', '5']
# ['11']
# ['9']
# ['11']
# ['11', '1']
# ['128']
# ['8']
# ['10']
# ['581']
# [['ZPO', 'Absatz'], ['128', '1']] is one legal norm in the label.
# [['BKleingG', 'Abs.', 'Nr.'], ['9', '1', '5']] is one legal norm in the label.
# [['BKleingG'], ['11']] is one legal norm in the label.
# [['BKleingG'], ['9']] is one legal norm in the label.
# [['Abs'], ['11']] is one legal norm in the label.
# [['BKleingG', 'Abs.'], ['11', '1']] is one legal norm in the label.
# [['ZPO'], ['128']] is one legal norm in the label.
# [['SchuldRAnpG'], ['8']] is one legal norm in the label.
# [['BKleingG'], ['10']] is one legal norm in the label.
# [['BGB'], ['581']] is one legal norm in the label.
# 0.0003648192624570577
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_009687_2010_KW35.xml
# EG Art. 82
# TKG § 21
# ['82']
# ['21']
# This file has label  ['EG Art. 82', 'TKG § 21']
# But something is missing or wrong within the text.
# 0.00039522086766181257
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/IIR5810.xml
# BewG 2005 138 Abs. 1 S. 2
# BewG 2005 138 Abs. 3 S. 1
# BewG 2005 145 Abs. 1 S. 2
# BewG 2005 145 Abs. 1 S. 3
# BewG 2005 146 Abs. 1
# BewG 2005 146 Abs. 4 S. 1
# BewG 2009 178 Abs. 1 S. 3
# ['2005', '138', '1', '2']
# ['2005', '138', '3', '1']
# ['2005', '145', '1', '2']
# ['2005', '145', '1', '3']
# ['2005', '146', '1']
# ['2005', '146', '4', '1']
# ['2009', '178', '1', '3']
# ['145', '1']
# ['146', '4']
# [['BewG', 'Abs.', 'S.'], ['2005', '138', '1', '2']] is one legal norm in the label.
# [['BewG', 'Abs.', 'S.'], ['2005', '138', '3', '1']] is one legal norm in the label.
# [['BewG', 'Abs.', 'S.'], ['2005', '145', '1', '2']] is one legal norm in the label.
# [['BewG', 'Abs.', 'S.'], ['2005', '145', '1', '3']] is one legal norm in the label.
# [['BewG', 'Abs.'], ['2005', '146', '1']] is one legal norm in the label.
# [['BewG', 'Abs.', 'S.'], ['2005', '146', '4', '1']] is one legal norm in the label.
# [['BewG', 'Abs.', 'S.'], ['2009', '178', '1', '3']] is one legal norm in the label.
# [['BewG', 'Abs.'], ['145', '1']] is one legal norm in the label.
# [['BewG', 'Abs.'], ['146', '4']] is one legal norm in the label.
# 0.00042562247286656737
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-FF_069295.xml
# GVG § 17a
# SpruchG § 16
# ZPO § 36 Abs. 1 Nr. 6
# ['17a']
# ['16']
# ['36', '1', '6']
# ['16']
# ['17a']
# ['36', '1']
# ['281']
# [['GVG'], ['17a']] is one legal norm in the label.
# [['SpruchG'], ['16']] is one legal norm in the label.
# [['ZPO', 'Abs.', 'Nr.'], ['36', '1', '6']] is one legal norm in the label.
# [['SpruchG'], ['16']] is one legal norm in the label.
# [['GVG'], ['17a']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['36', '1']] is one legal norm in the label.
# [['ZPO'], ['281']] is one legal norm in the label.
# 0.00045602407807132216
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_009366_2010_KW19.xml
# BGB § 675 Abs. 1
# BGB § 249
# ['675', '1']
# ['249']
# [['BGB', 'Abs.'], ['675', '1']] is one legal norm in the label.
# [['BGB'], ['249']] is one legal norm in the label.
# 0.00048642568327607696
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/6Sa142211.xml
# GG Art. 3 Abs. 1
# BGB 138 Abs. 1
# BGB 612 Abs. 2
# ZPO 520 Abs. 3
# TVBeschäftigteAusland
# ['3', '1']
# ['138', '1']
# ['612', '2']
# ['520', '3']
# ['2']
# ['4']
# ['55']
# ['18']
# ['24']
# ['3']
# [['GG', 'Abs.'], ['3', '1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['138', '1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['612', '2']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['520', '3']] is one legal norm in the label.
# [['TV'], ['2']] is one legal norm in the label.
# [['TV'], ['4']] is one legal norm in the label.
# [['BBesG'], ['55']] is one legal norm in the label.
# [['EuGVVO'], ['18']] is one legal norm in the label.
# [['TVöD-AT'], ['24']] is one legal norm in the label.
# [['GG'], ['3']] is one legal norm in the label.
# 0.0005168272884808318
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/1k148707.xml
# EStG 1999 5 Abs. 1 S. 1
# EStG 1999 5 Abs. 2a
# HGB 249 Abs. 1 S. 1
# SächsKAG 10 Abs. 1
# SächsKAG 10 Abs. 2
# ['1999', '5', '1', '1']
# ['1999', '5', '2a']
# ['249', '1', '1']
# ['10', '1']
# ['10', '2']
# ['10', '2']
# ['5']
# [['EStG', 'Abs.', 'S.'], ['1999', '5', '1', '1']] is one legal norm in the label.
# [['EStG', 'Abs.'], ['1999', '5', '2a']] is one legal norm in the label.
# [['HGB', 'Abs.', 'S.'], ['249', '1', '1']] is one legal norm in the label.
# [['SächsKAG', 'Abs.'], ['10', '1']] is one legal norm in the label.
# [['SächsKAG', 'Abs.'], ['10', '2']] is one legal norm in the label.
# [['SächsKAG', 'Abs.'], ['10', '2']] is one legal norm in the label.
# [['EStG'], ['5']] is one legal norm in the label.
# 0.0005472288936855866
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/IR54.xml
# GewStG 1999 2 Abs. 1
# GewStG 1999 2 Abs. 2 S. 2
# GewStG 1999 8 Nr. 1
# KStG 1999 14 Nr. 1
# KStG 1999 14 Nr. 2
# KStG 1999 14 Nr. 3
# DBA GBR 1964 Art. II Abs. 1 Buchst. f
# DBA GBR 1964 Art. II Abs. 1 Buchst. h Unterabs. i
# DBA GBR 1964 Art. II Abs. 1 Buchst. j
# DBA GBR 1964 Art. II Abs. 1 Buchst. l Unterabs. vi
# DBA GBR 1964 Art. III Abs. 1
# DBA GBR 1964 Art. XX Abs. 4
# DBA GBR 1964 Art. XX Abs. 5
# ['1999', '2', '1']
# ['1999', '2', '2', '2']
# ['1999', '8', '1']
# ['1999', '14', '1']
# ['1999', '14', '2']
# ['1999', '14', '3']
# ['1964', '1']
# ['1964', '1']
# ['1964', '1']
# ['1964', '1']
# ['1964', '1']
# ['1964', '4']
# ['1964', '5']
# ['2']
# ['14']
# [['GewStG', 'Abs.'], ['1999', '2', '1']] is one legal norm in the label.
# [['GewStG', 'Abs.', 'S.'], ['1999', '2', '2', '2']] is one legal norm in the label.
# [['GewStG', 'Nr.'], ['1999', '8', '1']] is one legal norm in the label.
# [['KStG', 'Nr.'], ['1999', '14', '1']] is one legal norm in the label.
# [['KStG', 'Nr.'], ['1999', '14', '2']] is one legal norm in the label.
# [['KStG', 'Nr.'], ['1999', '14', '3']] is one legal norm in the label.
# [['DBA', 'GBR', 'Abs.', 'Buchst.'], ['1964', '1']] is one legal norm in the label.
# [['DBA', 'GBR', 'Abs.', 'Buchst.', 'Unterabs.'], ['1964', '1']] is one legal norm in the label.
# [['DBA', 'GBR', 'Abs.', 'Buchst.'], ['1964', '1']] is one legal norm in the label.
# [['DBA', 'GBR', 'Abs.', 'Buchst.', 'Unterabs.'], ['1964', '1']] is one legal norm in the label.
# [['DBA', 'GBR', 'Abs.'], ['1964', '1']] is one legal norm in the label.
# [['DBA', 'GBR', 'XX', 'Abs.'], ['1964', '4']] is one legal norm in the label.
# [['DBA', 'GBR', 'XX', 'Abs.'], ['1964', '5']] is one legal norm in the label.
# [['GewStG'], ['2']] is one legal norm in the label.
# [['KStG'], ['14']] is one legal norm in the label.
# 0.0005776304988903415
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-NG_067722.xml
# GG Art. 14
# BGB § 839 i.V.m. Art. 34 GG
# BayStrWG Art. 17
# ['14']
# ['839', '34']
# ['17']
# ['14']
# ['8']
# [['GG'], ['14']] is one legal norm in the label.
# [['BGB'], ['839', '34']] is one legal norm in the label.
# [['BayStrWG'], ['17']] is one legal norm in the label.
# [['GG'], ['14']] is one legal norm in the label.
# [['FStrG'], ['8']] is one legal norm in the label.
# 0.0006080321040950963
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-FF_092999.xml
# BGB § 488
# BGB § 164 Abs. 2
# ['488']
# ['164', '2']
# ['488']
# [['BGB'], ['488']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['164', '2']] is one legal norm in the label.
# [['BGB'], ['488']] is one legal norm in the label.
# 0.000638433709299851
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-MU_092013.xml
# BGB § 280 Abs. 1
# BGB § 662
# HGB § 93
# HGB §§ 93 ff.
# HGB § 383
# HGB §§ 383 ff.
# ['280', '1']
# ['662']
# ['93']
# ['93']
# ['383']
# ['383']
# ['347']
# [['BGB', 'Abs.'], ['280', '1']] is one legal norm in the label.
# [['BGB'], ['662']] is one legal norm in the label.
# [['HGB'], ['93']] is one legal norm in the label.
# [['HGB'], ['93']] is one legal norm in the label.
# [['HGB'], ['383']] is one legal norm in the label.
# [['HGB'], ['383']] is one legal norm in the label.
# [['HGB'], ['347']] is one legal norm in the label.
# 0.0006688353145046058
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/10AZB1410.xml
# ArbGG 5 Abs. 1 S. 2
# SGB III 57
# SGB III 58
# ['5', '1', '2']
# ['57']
# ['58']
# ['2']
# ['57']
# ['5']
# ['58']
# [['ArbGG', 'Abs.', 'S.'], ['5', '1', '2']] is one legal norm in the label.
# [['SGB'], ['57']] is one legal norm in the label.
# [['SGB'], ['58']] is one legal norm in the label.
# [['Nr'], ['2']] is one legal norm in the label.
# [['SGBIII'], ['57']] is one legal norm in the label.
# [['ArbGG'], ['5']] is one legal norm in the label.
# [['SGBIII'], ['58']] is one legal norm in the label.
# 0.0006992369197093606
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-HM_065696.xml
# BGB § 823 Abs. 1
# BGB § 254
# ['823', '1']
# ['254']
# [['BGB', 'Abs.'], ['823', '1']] is one legal norm in the label.
# [['BGB'], ['254']] is one legal norm in the label.
# 0.0007296385249141154
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_011978_2013_KW01.xml
# BGB § 130
# BGB § 133 A, C
# BGB § 145
# BGB § 146
# BGB § 154
# BGB § 157 B
# BGB § 312g
# ['130']
# ['133']
# ['145']
# ['146']
# ['154']
# ['157']
# ['312g']
# This file has label  ['BGB § 130', 'BGB § 133 A, C', 'BGB § 145', 'BGB § 146', 'BGB § 154', 'BGB § 157 B', 'BGB § 312g']
# But something is missing or wrong within the text.
# 0.0007600401301188702
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/10_V_2745_14.xml
# FGO 48 Abs. 1 Nr. 1
# FGO 48 Abs. 1 Nr. 4
# FGO 48 Abs. 1 Nr. 5
# FGO 60 Abs. 3
# FGO 69 Abs. 3
# EStG 15 Abs. 1 S. 1 Nr. 2
# EStG 16 Abs. 1 Nr. 2
# EStG 16 Abs. 3
# EStG 34 Abs. 1
# EStG 34 Abs. 2 Nr. 1
# HGB 167
# HGB 168
# ['48', '1', '1']
# ['48', '1', '4']
# ['48', '1', '5']
# ['60', '3']
# ['69', '3']
# ['15', '1', '1', '2']
# ['16', '1', '2']
# ['16', '3']
# ['34', '1']
# ['34', '2', '1']
# ['167']
# ['168']
# 15 Abs. 1 Satz 1 Nr. 2 Satz 1, 1. Alt. Einkommensteuergesetz
# 15 Abs.1 Satz 1 Nr. 2 Satz 1, Halbsatz
# 15 Abs. 1 Satz 1 Nr. 2, Halbsatz
# ['15', '1']
# ['48', '1']
# ['69']
# ['16']
# ['34']
# ['15']
# [['FGO', 'Abs.', 'Nr.'], ['48', '1', '1']] is one legal norm in the label.
# [['FGO', 'Abs.', 'Nr.'], ['48', '1', '4']] is one legal norm in the label.
# [['FGO', 'Abs.', 'Nr.'], ['48', '1', '5']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['60', '3']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['69', '3']] is one legal norm in the label.
# [['EStG', 'Abs.', 'S.', 'Nr.'], ['15', '1', '1', '2']] is one legal norm in the label.
# [['EStG', 'Abs.', 'Nr.'], ['16', '1', '2']] is one legal norm in the label.
# [['EStG', 'Abs.'], ['16', '3']] is one legal norm in the label.
# [['EStG', 'Abs.'], ['34', '1']] is one legal norm in the label.
# [['EStG', 'Abs.', 'Nr.'], ['34', '2', '1']] is one legal norm in the label.
# [['HGB'], ['167']] is one legal norm in the label.
# [['HGB'], ['168']] is one legal norm in the label.
# [['Einkommensteuergesetz', 'Abs.'], ['15', '1']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['48', '1']] is one legal norm in the label.
# [['FGO'], ['69']] is one legal norm in the label.
# [['EStG'], ['16']] is one legal norm in the label.
# [['EStG'], ['34']] is one legal norm in the label.
# [['Halbsatz'], ['15']] is one legal norm in the label.
# 0.0007904417353236251
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/8KO48814.xml
# GKG 66 Abs. 1 S. 1
# GKG 52 Abs. 2
# GKG 52 Abs. 3
# GKG 52 Abs. 4
# GKG 34
# GKG 3 Abs. 1
# GKG 45 Abs. 1 S. 2
# EStG 10d
# ['66', '1', '1']
# ['52', '2']
# ['52', '3']
# ['52', '4']
# ['34']
# ['3', '1']
# ['45', '1', '2']
# ['10d']
# ['52', '2']
# ['66']
# [['GKG', 'Abs.', 'S.'], ['66', '1', '1']] is one legal norm in the label.
# [['GKG', 'Abs.'], ['52', '2']] is one legal norm in the label.
# [['GKG', 'Abs.'], ['52', '3']] is one legal norm in the label.
# [['GKG', 'Abs.'], ['52', '4']] is one legal norm in the label.
# [['GKG'], ['34']] is one legal norm in the label.
# [['GKG', 'Abs.'], ['3', '1']] is one legal norm in the label.
# [['GKG', 'Abs.', 'S.'], ['45', '1', '2']] is one legal norm in the label.
# [['EStG'], ['10d']] is one legal norm in the label.
# [['GKG', 'Abs.'], ['52', '2']] is one legal norm in the label.
# [['GKG'], ['66']] is one legal norm in the label.
# 0.0008208433405283799
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-HB_093808.xml
# ZPO § 57
# ZPO § 567 Abs. 1
# FamFG § 113 Abs. 1
# FamFG § 266
# ['57']
# ['567', '1']
# ['113', '1']
# ['266']
# ['57', '1']
# ['113', '1']
# ['567', '1']
# ['567']
# ['57']
# [['ZPO'], ['57']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['567', '1']] is one legal norm in the label.
# [['FamFG', 'Abs.'], ['113', '1']] is one legal norm in the label.
# [['FamFG'], ['266']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['57', '1']] is one legal norm in the label.
# [['FamFG', 'Abs.'], ['113', '1']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['567', '1']] is one legal norm in the label.
# [['Rz'], ['567']] is one legal norm in the label.
# [['Rz'], ['57']] is one legal norm in the label.
# 0.0008512449457331347
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_010353_2011_KW19.xml
# ZPO § 4
# ZPO § 511
# ['4']
# ['511']
# ['522']
# ['511', '4']
# [['ZPO'], ['4']] is one legal norm in the label.
# [['ZPO'], ['511']] is one legal norm in the label.
# [['ZPO'], ['522']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['511', '4']] is one legal norm in the label.
# 0.0008816465509378895
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-JN_092184.xml
# BGB § 1626a
# FamFG § 78 Abs. 2
# FamFG § 155a
# ['1626a']
# ['78', '2']
# ['155a']
# ['76']
# ['1626']
# ['155']
# ['78', '2']
# [['BGB'], ['1626a']] is one legal norm in the label.
# [['FamFG', 'Abs.'], ['78', '2']] is one legal norm in the label.
# [['FamFG'], ['155a']] is one legal norm in the label.
# [['FamFG'], ['76']] is one legal norm in the label.
# [['BGB'], ['1626']] is one legal norm in the label.
# [['FamFG'], ['155']] is one legal norm in the label.
# [['FamFG', 'Abs.'], ['78', '2']] is one legal norm in the label.
# 0.0009120481561426443
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-SH_092517.xml
# BGBEG Art 11 Abs. 1 Alt 2
# BGBEG Art 25 Abs. 1
# BGB § 1945 Abs. 1 Halbs 1
# BGB § 2361
# GVG § 184
# ['11', '1', '2']
# ['25', '1']
# ['1945', '1', '1']
# ['2361']
# ['184']
# ['11', '1']
# ['1945']
# [['BGBEG', 'Abs.', 'Alt'], ['11', '1', '2']] is one legal norm in the label.
# [['BGBEG', 'Abs.'], ['25', '1']] is one legal norm in the label.
# [['BGB', 'Abs.', 'Halbs'], ['1945', '1', '1']] is one legal norm in the label.
# [['BGB'], ['2361']] is one legal norm in the label.
# [['GVG'], ['184']] is one legal norm in the label.
# [['EGBGB', 'Abs.'], ['11', '1']] is one legal norm in the label.
# [['BGB'], ['1945']] is one legal norm in the label.
# 0.0009424497613473991
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/2V156512.xml
# VersStG 7 Abs 1 Satz 1
# VersStG 7 Abs 3
# VersStG 10 Abs 2 und Abs 3
# AO 193 Abs 1
# ['7', '1', '1']
# ['7', '3']
# ['10', '2', '3']
# ['193', '1']
# 194 Abs. 1 Satz 4, 1. Halbsatz
# ['193', '1']
# ['10', '3']
# ['7']
# ['2']
# ['33']
# ['194']
# ['193']
# ['102']
# ['93']
# ['97']
# [['VersStG', 'Abs', 'Satz'], ['7', '1', '1']] is one legal norm in the label.
# [['VersStG', 'Abs'], ['7', '3']] is one legal norm in the label.
# [['VersStG', 'Abs', 'Abs'], ['10', '2', '3']] is one legal norm in the label.
# [['AO', 'Abs'], ['193', '1']] is one legal norm in the label.
# [['AO', 'Abs.'], ['193', '1']] is one legal norm in the label.
# [['VersStG', 'Abs.'], ['10', '3']] is one legal norm in the label.
# [['VersStG'], ['7']] is one legal norm in the label.
# [['VersStG'], ['2']] is one legal norm in the label.
# [['AO'], ['33']] is one legal norm in the label.
# [['Halbsatz'], ['194']] is one legal norm in the label.
# [['Rdnr'], ['193']] is one legal norm in the label.
# [['FGO'], ['102']] is one legal norm in the label.
# [['AO'], ['93']] is one legal norm in the label.
# [['AO'], ['97']] is one legal norm in the label.
# 0.0009728513665521539
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/7_K_605_14.xml
# EStG 9 Abs. 5 S. 2
# EStG 6 Abs. 1 Nr. 1a
# EStG 7 Abs. 4 S. 1 Nr. 2 Buchst. a
# EStG 9 Abs. 1 S. 3 Nr. 7
# ['9', '5', '2']
# ['6', '1', '1a']
# ['7', '4', '1', '2']
# ['9', '1', '3', '7']
# ['6']
# ['9']
# ['255']
# [['EStG', 'Abs.', 'S.'], ['9', '5', '2']] is one legal norm in the label.
# [['EStG', 'Abs.', 'Nr.'], ['6', '1', '1a']] is one legal norm in the label.
# [['EStG', 'Abs.', 'S.', 'Nr.', 'Buchst.'], ['7', '4', '1', '2']] is one legal norm in the label.
# [['EStG', 'Abs.', 'S.', 'Nr.'], ['9', '1', '3', '7']] is one legal norm in the label.
# [['EStG'], ['6']] is one legal norm in the label.
# [['EStG'], ['9']] is one legal norm in the label.
# [['HGB'], ['255']] is one legal norm in the label.
# 0.0010032529717569087
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-KO_065268.xml
# InsO § 115
# InsO § 116
# BGB § 675
# ['115']
# ['116']
# ['675']
# ['115']
# ['116']
# [['InsO'], ['115']] is one legal norm in the label.
# [['InsO'], ['116']] is one legal norm in the label.
# [['BGB'], ['675']] is one legal norm in the label.
# [['InsO'], ['115']] is one legal norm in the label.
# [['InsO'], ['116']] is one legal norm in the label.
# 0.0010336545769616635
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_010434_2011_KW22.xml
# BGB § 305c Abs. 2
# BGB § 307 Abs. 1 Bf.
# BGB § 307 Abs. 1 Ci.
# BGB § 308 Nr. 7 Buchst. a
# ['305c', '2']
# ['307', '1']
# ['307', '1']
# ['308', '7']
# ['12']
# ['8']
# ['649']
# ['307']
# ['308']
# [['BGB', 'Abs.'], ['305c', '2']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['307', '1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['307', '1']] is one legal norm in the label.
# [['BGB', 'Nr.', 'Buchst.'], ['308', '7']] is one legal norm in the label.
# [['Allgemeinen'], ['12']] is one legal norm in the label.
# [['Allgemeinen'], ['8']] is one legal norm in the label.
# [['BGB'], ['649']] is one legal norm in the label.
# [['BGB'], ['307']] is one legal norm in the label.
# [['BGB'], ['308']] is one legal norm in the label.
# 0.0010640561821664183
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-MU_075688.xml
# ZPO § 91
# ZPO § 104
# ZPO § 1040 Abs. 3 Satz 2
# ['91']
# ['104']
# ['1040', '3', '2']
# ['1040']
# ['104']
# ['11', '2']
# ['567']
# ['91']
# ['91', '2']
# [['ZPO'], ['91']] is one legal norm in the label.
# [['ZPO'], ['104']] is one legal norm in the label.
# [['ZPO', 'Abs.', 'Satz'], ['1040', '3', '2']] is one legal norm in the label.
# [['ZPO'], ['1040']] is one legal norm in the label.
# [['ZPO'], ['104']] is one legal norm in the label.
# [['RPflG', 'Abs.'], ['11', '2']] is one legal norm in the label.
# [['ZPO'], ['567']] is one legal norm in the label.
# [['Rz'], ['91']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['91', '2']] is one legal norm in the label.
# 0.001094457787371173
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/10AZB5110.xml
# ArbGG 2 Abs. 1 Nr. 3
# ArbGG 5 Abs. 1 S. 3
# BGB 623
# ['2', '1', '3']
# ['5', '1', '3']
# ['623']
# ['2']
# ['5']
# ['5']
# [['ArbGG', 'Abs.', 'Nr.'], ['2', '1', '3']] is one legal norm in the label.
# [['ArbGG', 'Abs.', 'S.'], ['5', '1', '3']] is one legal norm in the label.
# [['BGB'], ['623']] is one legal norm in the label.
# [['ArbGG'], ['2']] is one legal norm in the label.
# [['ArbGG'], ['5']] is one legal norm in the label.
# [['Nr'], ['5']] is one legal norm in the label.
# 0.0011248593925759281
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/6PB2511.xml
# BPersVG 69
# BPersVG 70
# BPersVG 75 Abs. 3 Nr. 11
# ArbSchG 5
# ArbSchG 6
# ['69']
# ['70']
# ['75', '3', '11']
# ['5']
# ['6']
# ['70']
# ['5']
# ['75', '3']
# ['69']
# [['BPersVG'], ['69']] is one legal norm in the label.
# [['BPersVG'], ['70']] is one legal norm in the label.
# [['BPersVG', 'Abs.', 'Nr.'], ['75', '3', '11']] is one legal norm in the label.
# [['ArbSchG'], ['5']] is one legal norm in the label.
# [['ArbSchG'], ['6']] is one legal norm in the label.
# [['BPersVG'], ['70']] is one legal norm in the label.
# [['ArbSchG'], ['5']] is one legal norm in the label.
# [['BPersVG', 'Abs.'], ['75', '3']] is one legal norm in the label.
# [['BPersVG'], ['69']] is one legal norm in the label.
# 0.001155260997780683
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/IIIB9512.xml
# GG Art 103 Abs 1
# FGO 116 Abs 3 Satz 3
# FGO 92 Abs 2
# FGO 93 Abs 1
# FGO 102
# FGO 82
# ZPO 391
# FGO 96 Abs 2
# ['103', '1']
# ['116', '3', '3']
# ['92', '2']
# ['93', '1']
# ['102']
# ['82']
# ['391']
# ['96', '2']
# ['96']
# ['116', '3']
# ['295', '1']
# ['119']
# ['115', '2']
# ['125', '2']
# [['GG', 'Abs'], ['103', '1']] is one legal norm in the label.
# [['FGO', 'Abs', 'Satz'], ['116', '3', '3']] is one legal norm in the label.
# [['FGO', 'Abs'], ['92', '2']] is one legal norm in the label.
# [['FGO', 'Abs'], ['93', '1']] is one legal norm in the label.
# [['FGO'], ['102']] is one legal norm in the label.
# [['FGO'], ['82']] is one legal norm in the label.
# [['ZPO'], ['391']] is one legal norm in the label.
# [['FGO', 'Abs'], ['96', '2']] is one legal norm in the label.
# [['FGO'], ['96']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['116', '3']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['295', '1']] is one legal norm in the label.
# [['FGO'], ['119']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['115', '2']] is one legal norm in the label.
# [['AO', 'Abs.'], ['125', '2']] is one legal norm in the label.
# 0.0011856626029854377
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/1ABR5309.xml
# BetrVG 99 Abs. 1 S. 1
# BetrVG 95 Abs. 3 S. 1
# BetrVG 21b
# ['99', '1', '1']
# ['95', '3', '1']
# ['21b']
# [['BetrVG', 'Abs.', 'S.'], ['99', '1', '1']] is one legal norm in the label.
# [['BetrVG', 'Abs.', 'S.'], ['95', '3', '1']] is one legal norm in the label.
# [['BetrVG'], ['21b']] is one legal norm in the label.
# 0.0012160642081901925
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/IXB13811.xml
# EStG 17 Abs 4
# FGO 115 Abs 2 Nr 1
# EStG 17 Abs 1
# ['17', '4']
# ['115', '2', '1']
# ['17', '1']
# ['115', '2']
# [['EStG', 'Abs'], ['17', '4']] is one legal norm in the label.
# [['FGO', 'Abs', 'Nr'], ['115', '2', '1']] is one legal norm in the label.
# [['EStG', 'Abs'], ['17', '1']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['115', '2']] is one legal norm in the label.
# 0.0012464658133949473
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-MU_064791.xml
# ZPO § 103
# ZPO § 104
# RVG-VV Nr. 3200
# RVG-VV Nr. 3201
# ['103']
# ['104']
# ['3200']
# ['3201']
# [['ZPO'], ['103']] is one legal norm in the label.
# [['ZPO'], ['104']] is one legal norm in the label.
# [['RVG-VV', 'Nr.'], ['3200']] is one legal norm in the label.
# [['RVG-VV', 'Nr.'], ['3201']] is one legal norm in the label.
# 0.001276867418599702
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_012444_2013_KW26.xml
# InsO § 290
# InsO § 296
# InsO § 302 Nr. 1
# InsO § 184 Abs. 1
# ['290']
# ['296']
# ['302', '1']
# ['184', '1']
# ['574']
# [['InsO'], ['290']] is one legal norm in the label.
# [['InsO'], ['296']] is one legal norm in the label.
# [['InsO', 'Nr.'], ['302', '1']] is one legal norm in the label.
# [['InsO', 'Abs.'], ['184', '1']] is one legal norm in the label.
# [['ZPO'], ['574']] is one legal norm in the label.
# 0.001307269023804457
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_011334_2012_KW17.xml
# InsO § 352 Abs. 1 Satz 1
# ZPO § 240
# ['352', '1', '1']
# ['240']
# ['32']
# ['823', '2']
# ['13', '1']
# ['15', '1']
# ['352', '1']
# ['343']
# ['240']
# ['240']
# ['15', '1']
# ['298']
# ['352']
# [['InsO', 'Abs.', 'Satz'], ['352', '1', '1']] is one legal norm in the label.
# [['ZPO'], ['240']] is one legal norm in the label.
# [['KWG'], ['32']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['823', '2']] is one legal norm in the label.
# [['LugÜ', 'Abs.'], ['13', '1']] is one legal norm in the label.
# [['LugÜ', 'Abs.'], ['15', '1']] is one legal norm in the label.
# [['InsO', 'Abs.'], ['352', '1']] is one legal norm in the label.
# [['InsO'], ['343']] is one legal norm in the label.
# [['ZPO'], ['240']] is one legal norm in the label.
# [['Rz'], ['240']] is one legal norm in the label.
# [['EuGVVO', 'Abs.'], ['15', '1']] is one legal norm in the label.
# [['SchKG'], ['298']] is one legal norm in the label.
# [['Rz'], ['352']] is one legal norm in the label.
# 0.0013376706290092117
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/14_K_1376_12.xml
# UStG 2010 15 Abs. 1 S. 1 Nr. 1
# UStG 2010 15 Abs. 1 S. 1
# UStG 2010 15 Abs. 1 S. 2
# UStG 2010 15 Abs. 1 S. 3
# UStG 2010 2 Abs. 1 S. 1
# UStG 2010 14 Abs. 5 S. 1
# UStG 2010 14 Abs. 4
# UStG 2010 14c Abs. 2
# UStG 2010 17 Abs. 2 Nr. 2
# Richtlinie 2006/112/EG Art. 167
# Richtlinie 2006/112/EG Art. 65
# ['2010', '15', '1', '1', '1']
# ['2010', '15', '1', '1']
# ['2010', '15', '1', '2']
# ['2010', '15', '1', '3']
# ['2010', '2', '1', '1']
# ['2010', '14', '5', '1']
# ['2010', '14', '4']
# ['2010', '14c', '2']
# ['2010', '17', '2', '2']
# ['2006', '167']
# ['2006', '65']
# This file has label  ['UStG 2010 15 Abs. 1 S. 1 Nr. 1', 'UStG 2010 15 Abs. 1 S. 1', 'UStG 2010 15 Abs. 1 S. 2', 'UStG 2010 15 Abs. 1 S. 3', 'UStG 2010 2 Abs. 1 S. 1', 'UStG 2010 14 Abs. 5 S. 1', 'UStG 2010 14 Abs. 4', 'UStG 2010 14c Abs. 2', 'UStG 2010 17 Abs. 2 Nr. 2', 'Richtlinie 2006/112/EG Art. 167', 'Richtlinie 2006/112/EG Art. 65']
# But something is missing or wrong within the text.
# 0.0013680722342139665
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-MU_092761.xml
# GG Art. 13 Abs. 1
# GG Art. 2
# PAG (Bayern) Art. 23 Abs. 1
# PAG (Bayern) Art. 24
# ['13', '1']
# ['2']
# ['23', '1']
# ['24']
# 23, 24 PAG
# ['62']
# ['13', '2']
# [['GG', 'Abs.'], ['13', '1']] is one legal norm in the label.
# [['GG'], ['2']] is one legal norm in the label.
# [['PAG', 'Abs.'], ['23', '1']] is one legal norm in the label.
# [['PAG'], ['24']] is one legal norm in the label.
# [['FamFG'], ['62']] is one legal norm in the label.
# [['GG', 'Abs.'], ['13', '2']] is one legal norm in the label.
# 0.0013984738394187213
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/XIB8011.xml
# UStG 15 Abs 1
# FGO 115 Abs 2 Nr 2
# UStG 14 Abs 1 Satz 2
# ['15', '1']
# ['115', '2', '2']
# ['14', '1', '2']
# ['116', '3']
# [['UStG', 'Abs'], ['15', '1']] is one legal norm in the label.
# [['FGO', 'Abs', 'Nr'], ['115', '2', '2']] is one legal norm in the label.
# [['UStG', 'Abs', 'Satz'], ['14', '1', '2']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['116', '3']] is one legal norm in the label.
# 0.001428875444623476
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/2K567904.xml
# UStG 18 Abs 9 Satz 5
# UStDV §§ 59 ff
# RL 86/560/EWG Art 4 Abs 1 und Abs 2
# AO 150 Abs 3 Satz 1
# UStG 18 Abs 9 Satz 3
# ['18', '9', '5']
# ['59']
# ['86', '4', '1', '2']
# ['150', '3', '1']
# ['18', '9', '3']
# This file has label  ['UStG 18 Abs 9 Satz 5', 'UStDV §§ 59 ff', 'RL 86/560/EWG Art 4 Abs 1 und Abs 2', 'AO 150 Abs 3 Satz 1', 'UStG 18 Abs 9 Satz 3']
# But something is missing or wrong within the text.
# 0.0014592770498282309
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/4Ta17109.xml
# GKG 42
# GKG 63
# GKG 68
# ['42']
# ['63']
# ['68']
# ['68', '1']
# ['63']
# ['42', '3']
# [['GKG'], ['42']] is one legal norm in the label.
# [['GKG'], ['63']] is one legal norm in the label.
# [['GKG'], ['68']] is one legal norm in the label.
# [['GKG', 'Abs.'], ['68', '1']] is one legal norm in the label.
# [['GKG'], ['63']] is one legal norm in the label.
# [['GKG', 'Abs.'], ['42', '3']] is one legal norm in the label.
# 0.0014896786550329857
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-FF_077901.xml
# BGB § 249
# BGB § 280
# ['249']
# ['280']
# ['287']
# [['BGB'], ['249']] is one legal norm in the label.
# [['BGB'], ['280']] is one legal norm in the label.
# [['ZPO'], ['287']] is one legal norm in the label.
# 0.0015200802602377405
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/5Sa25212.xml
# ArbZG 4
# BGB 615
# BGB §§ 293 ff.
# GewO 106
# ['4']
# ['615']
# ['293']
# ['106']
# ['4']
# ['9']
# ['64']
# ['66']
# ['615']
# ['295']
# ['106']
# ['4']
# ['4']
# [['ArbZG'], ['4']] is one legal norm in the label.
# [['BGB'], ['615']] is one legal norm in the label.
# [['BGB'], ['293']] is one legal norm in the label.
# [['GewO'], ['106']] is one legal norm in the label.
# [['ArbZG'], ['4']] is one legal norm in the label.
# [['Betriebsvereinbarung'], ['9']] is one legal norm in the label.
# [['ArbGG'], ['64']] is one legal norm in the label.
# [['ArbGG'], ['66']] is one legal norm in the label.
# [['BGB'], ['615']] is one legal norm in the label.
# [['BGB'], ['295']] is one legal norm in the label.
# [['GewO'], ['106']] is one legal norm in the label.
# [['Rn'], ['4']] is one legal norm in the label.
# [['TVG'], ['4']] is one legal norm in the label.
# 0.0015504818654424953
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/7ABR1010.xml
# BetrVG 99 Abs. 1 S. 1
# BetrVG 99 Abs. 1 S. 2
# BetrVG 101
# BetrVG 87 Abs. 1 Nr. 10
# GG Art. 9 Abs. 3 S. 1
# GG Art. 9 Abs. 3 S. 2
# TVG 3 Abs. 2
# TVG 4 Abs. 1 S. 1
# TVG 4 Abs. 3
# ZPO 253 Abs. 2 Nr. 2
# ['99', '1', '1']
# ['99', '1', '2']
# ['101']
# ['87', '1', '10']
# ['9', '3', '1']
# ['9', '3', '2']
# ['3', '2']
# ['4', '1', '1']
# ['4', '3']
# ['253', '2', '2']
# ['99', '1']
# ['4']
# ['87', '1']
# [['BetrVG', 'Abs.', 'S.'], ['99', '1', '1']] is one legal norm in the label.
# [['BetrVG', 'Abs.', 'S.'], ['99', '1', '2']] is one legal norm in the label.
# [['BetrVG'], ['101']] is one legal norm in the label.
# [['BetrVG', 'Abs.', 'Nr.'], ['87', '1', '10']] is one legal norm in the label.
# [['GG', 'Abs.', 'S.'], ['9', '3', '1']] is one legal norm in the label.
# [['GG', 'Abs.', 'S.'], ['9', '3', '2']] is one legal norm in the label.
# [['TVG', 'Abs.'], ['3', '2']] is one legal norm in the label.
# [['TVG', 'Abs.', 'S.'], ['4', '1', '1']] is one legal norm in the label.
# [['TVG', 'Abs.'], ['4', '3']] is one legal norm in the label.
# [['ZPO', 'Abs.', 'Nr.'], ['253', '2', '2']] is one legal norm in the label.
# [['BetrVG', 'Abs.'], ['99', '1']] is one legal norm in the label.
# [['TVG'], ['4']] is one legal norm in the label.
# [['BetrVG', 'Abs.'], ['87', '1']] is one legal norm in the label.
# 0.0015808834706472503
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-KO_082381.xml
# BGB § 1684
# FamFG § 81 Abs 1 Nr 2
# FamGKG § 20
# ['1684']
# ['81', '1', '2']
# ['20']
# [['BGB'], ['1684']] is one legal norm in the label.
# [['FamFG', 'Abs', 'Nr'], ['81', '1', '2']] is one legal norm in the label.
# [['FamGKG'], ['20']] is one legal norm in the label.
# 0.001611285075852005
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_012594_2013_KW33.xml
# BGB § 2329 Abs. 1
# ZPO § 720a
# ZPO § 864 Abs. 2
# ZPO § 867 Abs. 1
# ['2329', '1']
# ['720a']
# ['864', '2']
# ['867', '1']
# ['867', '2']
# ['2329']
# ['720a']
# ['1113']
# ['78']
# ['720']
# ['864', '2']
# ['864']
# ['419']
# ['1990']
# ['867']
# ['866']
# ['803']
# ['131']
# [['BGB', 'Abs.'], ['2329', '1']] is one legal norm in the label.
# [['ZPO'], ['720a']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['864', '2']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['867', '1']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['867', '2']] is one legal norm in the label.
# [['BGB'], ['2329']] is one legal norm in the label.
# [['ZPO'], ['720a']] is one legal norm in the label.
# [['BGB'], ['1113']] is one legal norm in the label.
# [['GBO'], ['78']] is one legal norm in the label.
# [['Rz'], ['720']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['864', '2']] is one legal norm in the label.
# [['Rz'], ['864']] is one legal norm in the label.
# [['BGB'], ['419']] is one legal norm in the label.
# [['BGB'], ['1990']] is one legal norm in the label.
# [['Rz'], ['867']] is one legal norm in the label.
# [['ZPO'], ['866']] is one legal norm in the label.
# [['ZPO'], ['803']] is one legal norm in the label.
# [['KostO'], ['131']] is one legal norm in the label.
# 0.0016416866810567599
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/6Sa5311.xml
# BGB 613a
# BGB 315
# BGB 611
# ['613a']
# ['315']
# ['611']
# ['613a']
# ['315']
# ['12', '1']
# ['15']
# ['315']
# [['BGB'], ['613a']] is one legal norm in the label.
# [['BGB'], ['315']] is one legal norm in the label.
# [['BGB'], ['611']] is one legal norm in the label.
# [['BGB'], ['613a']] is one legal norm in the label.
# [['BGB'], ['315']] is one legal norm in the label.
# [['GG', 'Abs.'], ['12', '1']] is one legal norm in the label.
# [['KSchG'], ['15']] is one legal norm in the label.
# [['Hs'], ['315']] is one legal norm in the label.
# 0.0016720882862615147
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/2K10311.xml
# EStG § 20 Abs. 1 Nr. 7
# EStG § 20 Abs. 2 Satz 1 Nr. 4 Satz 1 Buchst. c
# EStG § 20 Abs. 2 Satz 1 Nr. 4 Satz 2 erste Halbsatz
# ['20', '1', '7']
# ['20', '2', '1', '4', '1']
# ['20', '2', '1', '4', '2']
# 52a Abs. 10 Satz 7, 2. Hs
# 20 Abs. 2 Satz 1 Nr. 4 Satz 2, 1. Hs
# 20 Abs. 2 Satz 1 Nr. 4 Satz 2, 1. Hs
# ['20', '1']
# ['23']
# ['20', '2']
# [['EStG', 'Abs.', 'Nr.'], ['20', '1', '7']] is one legal norm in the label.
# [['EStG', 'Abs.', 'Satz', 'Nr.', 'Satz', 'Buchst.'], ['20', '2', '1', '4', '1']] is one legal norm in the label.
# [['EStG', 'Abs.', 'Satz', 'Nr.', 'Satz', 'erste'], ['20', '2', '1', '4', '2']] is one legal norm in the label.
# [['EStG', 'Abs.'], ['20', '1']] is one legal norm in the label.
# [['EStG'], ['23']] is one legal norm in the label.
# [['Hs', 'Abs.'], ['20', '2']] is one legal norm in the label.
# 0.0017024898914662695
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/6P511.xml
# NWPersVG 65
# SGB IX 84 Abs. 2
# ['65']
# ['84', '2']
# 3 Abs. 2 Satz 2 Nr. 4, Abs. 4 Satz 2 DSG
# 6, 14 Abs. 4 DSG
# ['84', '2']
# ['65', '3']
# ['65', '1']
# ['73']
# ['64']
# ['29']
# ['84']
# ['10']
# ['68']
# [['NWPersVG'], ['65']] is one legal norm in the label.
# [['SGB', 'IX', 'Abs.'], ['84', '2']] is one legal norm in the label.
# [['SGBIX', 'Abs.'], ['84', '2']] is one legal norm in the label.
# [['NWPersVG', 'Abs.'], ['65', '3']] is one legal norm in the label.
# [['Satz', 'Abs.'], ['65', '1']] is one legal norm in the label.
# [['BlnPersVG'], ['73']] is one legal norm in the label.
# [['NWPersVG'], ['64']] is one legal norm in the label.
# [['DSG'], ['29']] is one legal norm in the label.
# [['LBG'], ['84']] is one legal norm in the label.
# [['Rn'], ['10']] is one legal norm in the label.
# [['Rn'], ['68']] is one legal norm in the label.
# 0.0017328914966710243
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/IIIB22311.xml
# ZPO 381 Abs 1 Satz 1
# ZPO 380 Abs 1
# ZPO 381 Abs 1 Satz 3
# FGO 82
# ['381', '1', '1']
# ['380', '1']
# ['381', '1', '3']
# ['82']
# ['82']
# ['381', '1']
# [['ZPO', 'Abs', 'Satz'], ['381', '1', '1']] is one legal norm in the label.
# [['ZPO', 'Abs'], ['380', '1']] is one legal norm in the label.
# [['ZPO', 'Abs', 'Satz'], ['381', '1', '3']] is one legal norm in the label.
# [['FGO'], ['82']] is one legal norm in the label.
# [['FGO'], ['82']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['381', '1']] is one legal norm in the label.
# 0.001763293101875779
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/13V280212.xml
# AO 350
# AO 361
# FGO 40 Abs 2
# FGO 40 Abs 3
# FGO 69
# GG Art 19 Abs 4
# GG Art 28 Abs 2 Satz 3
# GG Art 108 Abs 2 und Abs 4
# AO 78
# ['350']
# ['361']
# ['40', '2']
# ['40', '3']
# ['69']
# ['19', '4']
# ['28', '2', '3']
# ['108', '2', '4']
# ['78']
# 171 Abs. 3a Satz 2, 2. Halbsatz
# ['350']
# ['40', '3']
# ['19', '4']
# ['21']
# ['360', '2']
# ['186']
# ['69']
# ['171']
# ['171']
# ['60']
# [['AO'], ['350']] is one legal norm in the label.
# [['AO'], ['361']] is one legal norm in the label.
# [['FGO', 'Abs'], ['40', '2']] is one legal norm in the label.
# [['FGO', 'Abs'], ['40', '3']] is one legal norm in the label.
# [['FGO'], ['69']] is one legal norm in the label.
# [['GG', 'Abs'], ['19', '4']] is one legal norm in the label.
# [['GG', 'Abs', 'Satz'], ['28', '2', '3']] is one legal norm in the label.
# [['GG', 'Abs', 'Abs'], ['108', '2', '4']] is one legal norm in the label.
# [['AO'], ['78']] is one legal norm in the label.
# [['AO'], ['350']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['40', '3']] is one legal norm in the label.
# [['GG', 'Abs.'], ['19', '4']] is one legal norm in the label.
# [['FVG'], ['21']] is one legal norm in the label.
# [['AO', 'Abs.'], ['360', '2']] is one legal norm in the label.
# [['AO'], ['186']] is one legal norm in the label.
# [['FGO'], ['69']] is one legal norm in the label.
# [['AO'], ['171']] is one legal norm in the label.
# [['Halbsatz'], ['171']] is one legal norm in the label.
# [['FGO'], ['60']] is one legal norm in the label.
# 0.0017936947070805339
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-MU_068815.xml
# BGB § 1666
# BGB § 1684 Abs. 1
# ['1666']
# ['1684', '1']
# ['1684', '3']
# ['1666']
# [['BGB'], ['1666']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['1684', '1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['1684', '3']] is one legal norm in the label.
# [['BGB'], ['1666']] is one legal norm in the label.
# 0.0018240963122852887
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/8AZR70909.xml
# BGB 613a
# ZPO 233
# ZPO 234
# ['613a']
# ['233']
# ['234']
# This file has label  ['BGB 613a', 'ZPO 233', 'ZPO 234']
# But something is missing or wrong within the text.
# 0.0018544979174900434
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-CE_093078.xml
# HöfeVfO § 3 Abs. 1 Nr. 2
# HöfeVfO § 8
# GNotKG § 22
# GNotKG § 34
# GNotKG § 36 Abs. 1
# GNotKG § 48
# ['3', '1', '2']
# ['8']
# ['22']
# ['34']
# ['36', '1']
# ['48']
# 3, 8 HöfeVfO
# 3, 8 HöfeVfO
# 6 Abs. 4, 7 Abs. 1 HöfeVfO
# ['3']
# ['18']
# ['1']
# ['81']
# [['HöfeVfO', 'Abs.', 'Nr.'], ['3', '1', '2']] is one legal norm in the label.
# [['HöfeVfO'], ['8']] is one legal norm in the label.
# [['GNotKG'], ['22']] is one legal norm in the label.
# [['GNotKG'], ['34']] is one legal norm in the label.
# [['GNotKG', 'Abs.'], ['36', '1']] is one legal norm in the label.
# [['GNotKG'], ['48']] is one legal norm in the label.
# [['HöfeVfO'], ['3']] is one legal norm in the label.
# [['HöfeVfO'], ['18']] is one legal norm in the label.
# [['HöfeO'], ['1']] is one legal norm in the label.
# [['GNotKG'], ['81']] is one legal norm in the label.
# 0.0018848995226947982
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/15Sa98011.xml
# BGB 134
# BGB 812
# BGB 823 II
# StGB 263
# ['134']
# ['812']
# ['823']
# ['263']
# ['611']
# ['812']
# [['BGB'], ['134']] is one legal norm in the label.
# [['BGB'], ['812']] is one legal norm in the label.
# [['BGB'], ['823']] is one legal norm in the label.
# [['StGB'], ['263']] is one legal norm in the label.
# [['BGB'], ['611']] is one legal norm in the label.
# [['BGB'], ['812']] is one legal norm in the label.
# 0.001915301127899553
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-KL_073835.xml
# BGB §§ 1896 ff.
# BGB §§ 1626 ff.
# FamFG § 151 Nr. 1
# ['1896']
# ['1626']
# ['151', '1']
# ['1626']
# [['BGB'], ['1896']] is one legal norm in the label.
# [['BGB'], ['1626']] is one legal norm in the label.
# [['FamFG', 'Nr.'], ['151', '1']] is one legal norm in the label.
# [['BGB'], ['1626']] is one legal norm in the label.
# 0.0019457027331043078
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_010985_2011_KW51.xml
# EPÜ Art. 56
# PatG § 4
# ['56']
# ['4']
# [['EPÜ'], ['56']] is one legal norm in the label.
# [['PatG'], ['4']] is one legal norm in the label.
# 0.001976104338309063
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-DF_080238.xml
# GBO § 22
# BGB § 133
# BGB § 1754 Abs. 1
# BGB § 1772
# BGB § 2084
# BGB § 2100
# ['22']
# ['133']
# ['1754', '1']
# ['1772']
# ['2084']
# ['2100']
# ['71']
# [['GBO'], ['22']] is one legal norm in the label.
# [['BGB'], ['133']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['1754', '1']] is one legal norm in the label.
# [['BGB'], ['1772']] is one legal norm in the label.
# [['BGB'], ['2084']] is one legal norm in the label.
# [['BGB'], ['2100']] is one legal norm in the label.
# [['GBO'], ['71']] is one legal norm in the label.
# 0.0020065059435138174
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/13TaBV5209.xml
# ArbGG 98 Abs. 1 S. 2
# BetrVG 87 Abs. 1 Nr. 1
# BetrVG 87 Abs. 1 Nr. 7
# BetrVG 58 Abs. 1 S. 1
# ['98', '1', '2']
# ['87', '1', '1']
# ['87', '1', '7']
# ['58', '1', '1']
# ['84', '2']
# ['87', '1']
# [['ArbGG', 'Abs.', 'S.'], ['98', '1', '2']] is one legal norm in the label.
# [['BetrVG', 'Abs.', 'Nr.'], ['87', '1', '1']] is one legal norm in the label.
# [['BetrVG', 'Abs.', 'Nr.'], ['87', '1', '7']] is one legal norm in the label.
# [['BetrVG', 'Abs.', 'S.'], ['58', '1', '1']] is one legal norm in the label.
# [['SGBIX', 'Abs.'], ['84', '2']] is one legal norm in the label.
# [['BetrVG', 'Abs.'], ['87', '1']] is one legal norm in the label.
# 0.0020369075487185724
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-NG_084485.xml
# ZPO § 97 Abs. 1
# ZPO § 711
# ZPO § 543 Abs. 2 S. 1
# ZPO § 522 Abs. 2
# ['97', '1']
# ['711']
# ['543', '2', '1']
# ['522', '2']
# [['ZPO', 'Abs.'], ['97', '1']] is one legal norm in the label.
# [['ZPO'], ['711']] is one legal norm in the label.
# [['ZPO', 'Abs.', 'S.'], ['543', '2', '1']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['522', '2']] is one legal norm in the label.
# 0.002067309153923327
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/3AZR21609.xml
# BetrVG 75
# BetrAVG 1b Abs. 1
# BetrAVG 1b Abs. 4
# ['75']
# ['1b', '1']
# ['1b', '4']
# ['307']
# ['75']
# ['1b', '1']
# ['112']
# ['112']
# [['BetrVG'], ['75']] is one legal norm in the label.
# [['BetrAVG', 'Abs.'], ['1b', '1']] is one legal norm in the label.
# [['BetrAVG', 'Abs.'], ['1b', '4']] is one legal norm in the label.
# [['Nr'], ['307']] is one legal norm in the label.
# [['BetrVG'], ['75']] is one legal norm in the label.
# [['BetrAVG', 'Abs.'], ['1b', '1']] is one legal norm in the label.
# [['Nr'], ['112']] is one legal norm in the label.
# [['BetrVG'], ['112']] is one legal norm in the label.
# 0.002097710759128082
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-FF_083670.xml
# StGB § 129a
# StGB § 129b
# BGB § 823
# BGB § 1004
# GG Art. 1
# GG Art. 2 Abs. 1
# ['129a']
# ['129b']
# ['823']
# ['1004']
# ['1']
# ['2', '1']
# ['823']
# ['129a']
# [['StGB'], ['129a']] is one legal norm in the label.
# [['StGB'], ['129b']] is one legal norm in the label.
# [['BGB'], ['823']] is one legal norm in the label.
# [['BGB'], ['1004']] is one legal norm in the label.
# [['GG'], ['1']] is one legal norm in the label.
# [['GG', 'Abs.'], ['2', '1']] is one legal norm in the label.
# [['BGB'], ['823']] is one legal norm in the label.
# [['StGB'], ['129a']] is one legal norm in the label.
# 0.0021281123643328366
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/15Ta34412.xml
# ZPO 114
# ZPO 139 I 2
# ['114']
# ['139', '2']
# ['114']
# [['ZPO'], ['114']] is one legal norm in the label.
# ...
# BGB § 478 Abs. 2
# BGB § 823 Abs. 1
# ProdHaftG § 1
# ['280', '1']
# ['439', '2']
# ['478', '2']
# ['823', '1']
# ['1']
# ['439', '2']
# ['127']
# [['BGB', 'Abs.'], ['280', '1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['439', '2']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['478', '2']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['823', '1']] is one legal norm in the label.
# [['ProdHaftG'], ['1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['439', '2']] is one legal norm in the label.
# [['ZPO'], ['127']] is one legal norm in the label.
# 0.10868573860699846
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/3AZR27911.xml
# BetrAVG 1b Abs. 1 S. 4
# BGB 151 S. 1
# ZPO 894 S. 1
# ['1b', '1', '4']
# ['151', '1']
# ['894', '1']
# ['5']
# ['5']
# ['1b', '1']
# ['1']
# ['9']
# [['BetrAVG', 'Abs.', 'S.'], ['1b', '1', '4']] is one legal norm in the label.
# [['BGB', 'S.'], ['151', '1']] is one legal norm in the label.
# [['ZPO', 'S.'], ['894', '1']] is one legal norm in the label.
# [['Buchst'], ['5']] is one legal norm in the label.
# [['SGBVI'], ['5']] is one legal norm in the label.
# [['BetrAVG', 'Abs.'], ['1b', '1']] is one legal norm in the label.
# [['Nr'], ['1']] is one legal norm in the label.
# [['Arbeitsvertrages'], ['9']] is one legal norm in the label.
# 0.1087161402122032
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_012389_2013_KW23.xml
# MarkenG § 26 Abs. 1 und 3
# MarkenG § 49 Abs. 1
# ['26', '1', '3']
# ['49', '1']
# ['26', '3']
# ['26']
# [['MarkenG', 'Abs.'], ['26', '1', '3']] is one legal norm in the label.
# [['MarkenG', 'Abs.'], ['49', '1']] is one legal norm in the label.
# [['MarkenG', 'Abs.'], ['26', '3']] is one legal norm in the label.
# [['Rz'], ['26']] is one legal norm in the label.
# 0.10874654181740796
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/5K511808.xml
# EStG 15 Abs. 1 S. 1 Nr. 2
# EStG 15 Abs. 2
# EStG 21 Abs. 1
# GewStG 2 Abs. 1 S. 2
# AO 173 Abs. 1 Nr. 1
# ['15', '1', '1', '2']
# ['15', '2']
# ['21', '1']
# ['2', '1', '2']
# ['173', '1', '1']
# ['173', '1']
# ['15']
# [['EStG', 'Abs.', 'S.', 'Nr.'], ['15', '1', '1', '2']] is one legal norm in the label.
# [['EStG', 'Abs.'], ['15', '2']] is one legal norm in the label.
# [['EStG', 'Abs.'], ['21', '1']] is one legal norm in the label.
# [['GewStG', 'Abs.', 'S.'], ['2', '1', '2']] is one legal norm in the label.
# [['AO', 'Abs.', 'Nr.'], ['173', '1', '1']] is one legal norm in the label.
# [['AO', 'Abs.'], ['173', '1']] is one legal norm in the label.
# [['EStG'], ['15']] is one legal norm in the label.
# 0.10877694342261271
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/13Sa49912.xml
# BGB 611 Abs. 1
# BGB 615 S. 1
# BGB 397
# BGB 133
# BGB 157
# BGB 397 Abs. 1
# ['611', '1']
# ['615', '1']
# ['397']
# ['133']
# ['157']
# ['397', '1']
# ['615']
# ['611', '1']
# ['133']
# [['BGB', 'Abs.'], ['611', '1']] is one legal norm in the label.
# [['BGB', 'S.'], ['615', '1']] is one legal norm in the label.
# [['BGB'], ['397']] is one legal norm in the label.
# [['BGB'], ['133']] is one legal norm in the label.
# [['BGB'], ['157']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['397', '1']] is one legal norm in the label.
# [['BGB'], ['615']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['611', '1']] is one legal norm in the label.
# [['BGB'], ['133']] is one legal norm in the label.
# 0.10880734502781747
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-ST_072535.xml
# BGB § 652
# BGB § 812 I 1 1. Alt
# BGB § 123
# ['652']
# ['812', '1', '1']
# ['123']
# 123, Rz
# ['124']
# [['BGB'], ['652']] is one legal norm in the label.
# [['BGB'], ['812', '1', '1']] is one legal norm in the label.
# [['BGB'], ['123']] is one legal norm in the label.
# [['BGB'], ['124']] is one legal norm in the label.
# 0.10883774663302222
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/BGH_010818_2011_KW44.xml
# MarkenG § 14 Abs. 2 Nr. 2
# ZPO § 91a
# ZPO § 139 Abs. 1 Satz 2
# ZPO § 156 Abs. 2 Nr. 1 und Abs. 4
# ['14', '2', '2']
# ['91a']
# ['139', '1', '2']
# ['156', '2', '1', '4']
# ['14', '2']
# ['139', '1']
# ['156', '2']
# ['91a']
# [['MarkenG', 'Abs.', 'Nr.'], ['14', '2', '2']] is one legal norm in the label.
# [['ZPO'], ['91a']] is one legal norm in the label.
# [['ZPO', 'Abs.', 'Satz'], ['139', '1', '2']] is one legal norm in the label.
# [['ZPO', 'Abs.', 'Nr.', 'Abs.'], ['156', '2', '1', '4']] is one legal norm in the label.
# [['MarkenG', 'Abs.'], ['14', '2']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['139', '1']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['156', '2']] is one legal norm in the label.
# [['ZPO'], ['91a']] is one legal norm in the label.
# 0.10886814823822698
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-DF_075516.xml
# EEG 2009 § 3 Nr. 1
# EEG 2009 § 19 Abs. 1
# ['2009', '3', '1']
# ['2009', '19', '1']
# 3 Nr. 1, Nr. 4, 19 Abs. 1 EEG
# ['3']
# ['19', '1']
# ['27', '1']
# ['18']
# ['3']
# [['EEG', 'Nr.'], ['2009', '3', '1']] is one legal norm in the label.
# [['EEG', 'Abs.'], ['2009', '19', '1']] is one legal norm in the label.
# [['EEG'], ['3']] is one legal norm in the label.
# [['EEG', 'Abs.'], ['19', '1']] is one legal norm in the label.
# [['Nr', 'Abs.'], ['27', '1']] is one legal norm in the label.
# [['EEG'], ['18']] is one legal norm in the label.
# [['Rz'], ['3']] is one legal norm in the label.
# 0.10889854984343174
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/8K360311.xml
# BewG 198
# BewG 157 Abs. 3
# BewG 179
# BewG 182
# BewG 196
# AO 362
# AO 365
# AO 173 Abs. 1 Nr. 2 S. 1
# AO 175 Abs. 1 Nr. 2
# BGB 133
# BGB 157
# ['198']
# ['157', '3']
# ['179']
# ['182']
# ['196']
# ['362']
# ['365']
# ['173', '1', '2', '1']
# ['175', '1', '2']
# ['133']
# ['157']
# ['362']
# ['198']
# ['173', '1']
# ['175', '1']
# [['BewG'], ['198']] is one legal norm in the label.
# [['BewG', 'Abs.'], ['157', '3']] is one legal norm in the label.
# [['BewG'], ['179']] is one legal norm in the label.
# [['BewG'], ['182']] is one legal norm in the label.
# [['BewG'], ['196']] is one legal norm in the label.
# [['AO'], ['362']] is one legal norm in the label.
# [['AO'], ['365']] is one legal norm in the label.
# [['AO', 'Abs.', 'Nr.', 'S.'], ['173', '1', '2', '1']] is one legal norm in the label.
# [['AO', 'Abs.', 'Nr.'], ['175', '1', '2']] is one legal norm in the label.
# [['BGB'], ['133']] is one legal norm in the label.
# [['BGB'], ['157']] is one legal norm in the label.
# [['AO'], ['362']] is one legal norm in the label.
# [['BewG'], ['198']] is one legal norm in the label.
# [['AO', 'Abs.'], ['173', '1']] is one legal norm in the label.
# [['AO', 'Abs.'], ['175', '1']] is one legal norm in the label.
# 0.10892895144863649
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/8C2212.xml
# AEUV Art. 49 Abs. 1
# AEUV Art. 56 Abs. 1
# AEUV Art. 57 Abs. 1
# AEUV Art. 57 Abs. 3
# AEUV Art. 267 Abs. 3
# GRC Art. 47
# GG Art. 12 Abs. 1
# GG Art. 19 Abs. 4
# GG Art. 20 Abs. 3
# GG Art. 34
# VwGO 113 Abs. 1 S. 4
# BGB 839
# StGB 284 Abs. 1
# GlüStV a.F. 1
# GlüStV a.F. 4 Abs. 1
# GlüStV a.F. 5
# GlüStV a.F. 9 Abs. 1 S. 3 Nr. 3
# GlüStV a.F. 10 Abs. 1
# GlüStV a.F. 10 Abs. 2
# GlüStV a.F. 10 Abs. 5
# GlüStV a.F. 19
# GlüStV a.F. 21
# AGGlüStV Art. 2 Abs. 1
# AGGlüStV Art. 2 Abs. 2
# AGGlüStV Art. 2 Abs. 3
# AGGlüStV Art. 2 Abs. 4
# ['49', '1']
# ['56', '1']
# ['57', '1']
# ['57', '3']
# ['267', '3']
# ['47']
# ['12', '1']
# ['19', '4']
# ['20', '3']
# ['34']
# ['113', '1', '4']
# ['839']
# ['284', '1']
# ['1']
# ['4', '1']
# ['5']
# ['9', '1', '3', '3']
# ['10', '1']
# ['10', '2']
# ['10', '5']
# ['19']
# ['21']
# ['2', '1']
# ['2', '2']
# ['2', '3']
# ['2', '4']
# ['9']
# ['113', '1']
# ['4']
# ['10']
# ['12']
# ['19', '4']
# ['42']
# [['AEUV', 'Abs.'], ['49', '1']] is one legal norm in the label.
# [['AEUV', 'Abs.'], ['56', '1']] is one legal norm in the label.
# [['AEUV', 'Abs.'], ['57', '1']] is one legal norm in the label.
# [['AEUV', 'Abs.'], ['57', '3']] is one legal norm in the label.
# [['AEUV', 'Abs.'], ['267', '3']] is one legal norm in the label.
# [['GRC'], ['47']] is one legal norm in the label.
# [['GG', 'Abs.'], ['12', '1']] is one legal norm in the label.
# [['GG', 'Abs.'], ['19', '4']] is one legal norm in the label.
# [['GG', 'Abs.'], ['20', '3']] is one legal norm in the label.
# [['GG'], ['34']] is one legal norm in the label.
# [['VwGO', 'Abs.', 'S.'], ['113', '1', '4']] is one legal norm in the label.
# [['BGB'], ['839']] is one legal norm in the label.
# [['StGB', 'Abs.'], ['284', '1']] is one legal norm in the label.
# [['GlüStV'], ['1']] is one legal norm in the label.
# [['GlüStV', 'Abs.'], ['4', '1']] is one legal norm in the label.
# [['GlüStV'], ['5']] is one legal norm in the label.
# [['GlüStV', 'Abs.', 'S.', 'Nr.'], ['9', '1', '3', '3']] is one legal norm in the label.
# [['GlüStV', 'Abs.'], ['10', '1']] is one legal norm in the label.
# [['GlüStV', 'Abs.'], ['10', '2']] is one legal norm in the label.
# [['GlüStV', 'Abs.'], ['10', '5']] is one legal norm in the label.
# [['GlüStV'], ['19']] is one legal norm in the label.
# [['GlüStV'], ['21']] is one legal norm in the label.
# [['AGGlüStV', 'Abs.'], ['2', '1']] is one legal norm in the label.
# [['AGGlüStV', 'Abs.'], ['2', '2']] is one legal norm in the label.
# [['AGGlüStV', 'Abs.'], ['2', '3']] is one legal norm in the label.
# [['AGGlüStV', 'Abs.'], ['2', '4']] is one legal norm in the label.
# [['GlüStV'], ['9']] is one legal norm in the label.
# [['VwGO', 'Abs.'], ['113', '1']] is one legal norm in the label.
# [['GlüStV'], ['4']] is one legal norm in the label.
# [['GlüStV'], ['10']] is one legal norm in the label.
# [['GG'], ['12']] is one legal norm in the label.
# [['GG', 'Abs.'], ['19', '4']] is one legal norm in the label.
# [['VwGO'], ['42']] is one legal norm in the label.
# 0.10895935305384125
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-CE_081683.xml
# InsO § 133
# InsO § 142
# ['133']
# ['142']
# ['133']
# [['InsO'], ['133']] is one legal norm in the label.
# [['InsO'], ['142']] is one legal norm in the label.
# [['InsO'], ['133']] is one legal norm in the label.
# 0.10898975465904599
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-MU_068432.xml
# HGB § 316
# HGB § 316 ff.
# HGB § 323 Abs. 1 S 3
# BGB § 826
# ['316']
# ['316']
# ['323', '1', '3']
# ['826']
# ['826']
# ['323', '1']
# [['HGB'], ['316']] is one legal norm in the label.
# [['HGB'], ['316']] is one legal norm in the label.
# [['HGB', 'Abs.'], ['323', '1', '3']] is one legal norm in the label.
# [['BGB'], ['826']] is one legal norm in the label.
# [['BGB'], ['826']] is one legal norm in the label.
# [['HGB', 'Abs.'], ['323', '1']] is one legal norm in the label.
# 0.10902015626425075
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/10C310.xml
# AufenthG 60 Abs. 1
# AsylVfG 26
# AsylVfG 73
# VwVfG 49 Abs. 2 S. 2
# VwVfG 48 Abs. 4
# GFK Art. 1 C Nr. 5
# GFK Art. 1 C Nr. 6
# Richtlinie 2004/83/EG Art. 2 Buchst. c
# Richtlinie 2004/83/EG Art. 2 Buchst. e
# Richtlinie 2004/83/EG Art. 4 Abs. 4
# Richtlinie 2004/83/EG Art. 8
# Richtlinie 2004/83/EG Art. 11 Abs. 1 Buchst. e
# Richtlinie 2004/83/EG Art. 11 Abs. 2
# ['60', '1']
# ['26']
# ['73']
# ['49', '2', '2']
# ['48', '4']
# ['1', '5']
# ['1', '6']
# ['2004', '2']
# ['2004', '2']
# ['2004', '4', '4']
# ['2004', '8']
# ['2004', '11', '1']
# ['2004', '11', '2']
# This file has label  ['AufenthG 60 Abs. 1', 'AsylVfG 26', 'AsylVfG 73', 'VwVfG 49 Abs. 2 S. 2', 'VwVfG 48 Abs. 4', 'GFK Art. 1 C Nr. 5', 'GFK Art. 1 C Nr. 6', 'Richtlinie 2004/83/EG Art. 2 Buchst. c', 'Richtlinie 2004/83/EG Art. 2 Buchst. e', 'Richtlinie 2004/83/EG Art. 4 Abs. 4', 'Richtlinie 2004/83/EG Art. 8', 'Richtlinie 2004/83/EG Art. 11 Abs. 1 Buchst. e', 'Richtlinie 2004/83/EG Art. 11 Abs. 2']
# But something is missing or wrong within the text.
# 0.10905055786945551
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/2AZR15311.xml
# KSchG 1 Abs. 2
# BGB 241 Abs. 2
# GG Art. 2 Abs. 1 iVm. Art. 1 Abs. 1
# BDSG 6b
# ['1', '2']
# ['241', '2']
# ['2', '1', '1', '1']
# ['6b']
# This file has label  ['KSchG 1 Abs. 2', 'BGB 241 Abs. 2', 'GG Art. 2 Abs. 1 iVm. Art. 1 Abs. 1', 'BDSG 6b']
# But something is missing or wrong within the text.
# 0.10908095947466026
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-MU_077512.xml
# ZPO § 1025 Abs. 1
# ZPO § 1025 Abs. 3
# ZPO § 1043 Abs. 1
# ZPO § 1035
# ['1025', '1']
# ['1025', '3']
# ['1043', '1']
# ['1035']
# ['27']
# ['28']
# ['1035']
# ['1025']
# ['322']
# [['ZPO', 'Abs.'], ['1025', '1']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['1025', '3']] is one legal norm in the label.
# [['ZPO', 'Abs.'], ['1043', '1']] is one legal norm in the label.
# [['ZPO'], ['1035']] is one legal norm in the label.
# [['EGBGB'], ['27']] is one legal norm in the label.
# [['EGBGB'], ['28']] is one legal norm in the label.
# [['ZPO'], ['1035']] is one legal norm in the label.
# [['ZPO'], ['1025']] is one legal norm in the label.
# [['Rz'], ['322']] is one legal norm in the label.
# 0.10911136107986502
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/5k240808.xml
# § 2a EStG
# Artikel 3 Abs. 4 DBA Frankreich
# ['3', '4']
# ['2a']
# ['165', '1']
# ['32b']
# [['Artikel', 'Abs.', 'DBA'], ['3', '4']] is one legal norm in the label.
# [['EStG'], ['2a']] is one legal norm in the label.
# [['AO', 'Abs.'], ['165', '1']] is one legal norm in the label.
# [['EStG'], ['32b']] is one legal norm in the label.
# 0.10914176268506977
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-BE_079234.xml
# UWG § 8 Abs. 1 Satz 1
# UWG § 12 Abs. 1 Satz 1
# ['8', '1', '1']
# ['12', '1', '1']
# 11 Abs. 1 Satz 1, Satz 2 Nr. 1, Nr. 2 LFGB
# 11 Abs. 1 Satz 1, Satz 2 Nr. 1, Nr. 2 LFGB
# ['11', '1']
# [['UWG', 'Abs.', 'Satz'], ['8', '1', '1']] is one legal norm in the label.
# [['UWG', 'Abs.', 'Satz'], ['12', '1', '1']] is one legal norm in the label.
# [['LFGB', 'Abs.'], ['11', '1']] is one legal norm in the label.
# 0.10917216429027453
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-KL_065258.xml
# BGB § 670
# BGB § 683 S. 1
# BGB § 823 Abs. 1
# BGB § 823 Abs. 2
# RheinSchPVO § 1.12 Nr. 4
# ['670']
# ['683', '1']
# ['823', '1']
# ['823', '2']
# ['1', '4']
# 1.12 Nr. 4, Rz
# 1.12 Nr. 3, Rz
# ['1']
# ['823', '2']
# [['BGB'], ['670']] is one legal norm in the label.
# [['BGB', 'S.'], ['683', '1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['823', '1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['823', '2']] is one legal norm in the label.
# [['RheinSchPVO', 'Nr.'], ['1', '4']] is one legal norm in the label.
# [['RheinSchPVO'], ['1']] is one legal norm in the label.
# [['BGB', 'Abs.'], ['823', '2']] is one legal norm in the label.
# 0.10920256589547928
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/4K92511.xml
# EStG 74 Abs. 1 S. 4
# EStG 74 Abs. 1 S. 1
# EStG 74 Abs. 1 S. 3
# SGB XII 42
# SGB XII 43 Abs. 2
# SGB XII 94 Abs. 1 S. 3
# SGB XII 30 Abs. 1 Nr. 2
# SGB XII 35 Abs. 1 S. 1
# BGB 1601
# BGB 1360
# AO 5
# AO 162
# FGO 102
# FGO 96 Abs. 1
# ['74', '1', '4']
# ['74', '1', '1']
# ['74', '1', '3']
# ['42']
# ['43', '2']
# ['94', '1', '3']
# ['30', '1', '2']
# ['35', '1', '1']
# ['1601']
# ['1360']
# ['5']
# ['162']
# ['102']
# ['96', '1']
# 27a, 28, Anlage
# ['74', '1']
# ['43', '2']
# ['66']
# ['74']
# ['30', '1']
# ['32', '4']
# ['5']
# ['42']
# ['35']
# [['EStG', 'Abs.', 'S.'], ['74', '1', '4']] is one legal norm in the label.
# [['EStG', 'Abs.', 'S.'], ['74', '1', '1']] is one legal norm in the label.
# [['EStG', 'Abs.', 'S.'], ['74', '1', '3']] is one legal norm in the label.
# [['SGB'], ['42']] is one legal norm in the label.
# [['SGB', 'Abs.'], ['43', '2']] is one legal norm in the label.
# [['SGB', 'Abs.', 'S.'], ['94', '1', '3']] is one legal norm in the label.
# [['SGB', 'Abs.', 'Nr.'], ['30', '1', '2']] is one legal norm in the label.
# [['SGB', 'Abs.', 'S.'], ['35', '1', '1']] is one legal norm in the label.
# [['BGB'], ['1601']] is one legal norm in the label.
# [['BGB'], ['1360']] is one legal norm in the label.
# [['AO'], ['5']] is one legal norm in the label.
# [['AO'], ['162']] is one legal norm in the label.
# [['FGO'], ['102']] is one legal norm in the label.
# [['FGO', 'Abs.'], ['96', '1']] is one legal norm in the label.
# [['EStG', 'Abs.'], ['74', '1']] is one legal norm in the label.
# [['SGBXII', 'Abs.'], ['43', '2']] is one legal norm in the label.
# [['EStG'], ['66']] is one legal norm in the label.
# [['Rz'], ['74']] is one legal norm in the label.
# [['SGBXII', 'Abs.'], ['30', '1']] is one legal norm in the label.
# [['EStG', 'Abs.'], ['32', '4']] is one legal norm in the label.
# [['AO'], ['5']] is one legal norm in the label.
# [['SGBXII'], ['42']] is one legal norm in the label.
# [['SGBXII'], ['35']] is one legal norm in the label.
# 0.10923296750068404
# /Users/jieyizhang/Desktop/Master_Thesis/labelled_files/OLG-BR_066021.xml

# %%
len(file_accuracy_scores)
# Out:
# 29328

# %%
sum(file_accuracy_scores)/len(file_accuracy_scores)
# Out:
# 0.688874086966586

# %%
len(file_precision_scores)
# Out:
# 29328

# %%
sum(file_precision_scores)/len(file_precision_scores)
# Out:
# 0.5488723859946862

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(file_scores, bins='auto')
# Out:
# (array([1.7600e+02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 5.0990e+03, 1.0000e+00, 3.0000e+01,
#         6.3000e+01, 7.3000e+01, 1.6500e+02, 4.1200e+02, 1.0100e+02,
#         2.0000e+01, 8.3700e+02, 3.4100e+02, 1.2300e+02, 6.3000e+01,
#         2.3320e+03, 3.8000e+01, 2.0300e+02, 6.1200e+02, 3.4000e+01,
#         1.6310e+03, 2.1900e+02, 1.0310e+03, 8.0900e+02, 4.2900e+02,
#         3.7200e+02, 2.4600e+02, 3.9000e+01, 1.3829e+04]),
#  array([-1.        , -0.96296296, -0.92592593, -0.88888889, -0.85185185,
#         -0.81481481, -0.77777778, -0.74074074, -0.7037037 , -0.66666667,
#         -0.62962963, -0.59259259, -0.55555556, -0.51851852, -0.48148148,
#         -0.44444444, -0.40740741, -0.37037037, -0.33333333, -0.2962963 ,
#         -0.25925926, -0.22222222, -0.18518519, -0.14814815, -0.11111111,
#         -0.07407407, -0.03703704,  0.        ,  0.03703704,  0.07407407,
#          0.11111111,  0.14814815,  0.18518519,  0.22222222,  0.25925926,
#          0.2962963 ,  0.33333333,  0.37037037,  0.40740741,  0.44444444,
#          0.48148148,  0.51851852,  0.55555556,  0.59259259,  0.62962963,
#          0.66666667,  0.7037037 ,  0.74074074,  0.77777778,  0.81481481,
#          0.85185185,  0.88888889,  0.92592593,  0.96296296,  1.        ]),
#  <a list of 54 Patch objects>)

# %%
from pylab import rcParams

rcParams['figure.figsize'] = 15, 5
plt.hist(length_score, bins='auto')
# Out:
# (array([2.500e+01, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         4.310e+03, 5.000e+00, 9.400e+01, 1.670e+02, 5.230e+02, 2.400e+01,
#         8.010e+02, 1.289e+03, 2.490e+02, 2.000e+01, 2.654e+03, 1.390e+02,
#         1.013e+03, 1.320e+02, 2.000e+01, 4.978e+03, 1.690e+02, 1.024e+03,
#         1.650e+02, 2.270e+03, 3.300e+01, 3.040e+02, 1.107e+03, 1.160e+02,
#         6.040e+02, 4.420e+02, 1.560e+02, 7.700e+01, 6.000e+00, 1.000e+00,
#         4.219e+03, 0.000e+00, 1.000e+00, 3.000e+00, 1.000e+00, 3.900e+01,
#         0.000e+00, 7.300e+01, 4.000e+00, 1.970e+02, 0.000e+00, 0.000e+00,
#         1.800e+01, 0.000e+00, 0.000e+00, 5.620e+02, 0.000e+00, 2.000e+00,
#         1.800e+01, 0.000e+00, 1.310e+02, 4.000e+00, 2.600e+01, 0.000e+00,
#         1.200e+01, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         4.290e+02, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00,
#         5.000e+00, 1.000e+01, 0.000e+00, 0.000e+00, 4.600e+01, 1.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 1.780e+02, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 2.100e+01, 0.000e+00, 4.000e+00, 0.000e+00,
#         3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.360e+02, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 5.000e+00, 0.000e+00, 0.000e+00, 1.800e+01, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 7.700e+01, 0.000e+00, 0.000e+00,
#         1.000e+00, 8.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         5.500e+01, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 3.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 2.100e+01, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.300e+01, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.600e+01, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         8.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 3.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         5.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-1.        , -0.96666667, -0.93333333, -0.9       , -0.86666667,
#         -0.83333333, -0.8       , -0.76666667, -0.73333333, -0.7       ,
#         -0.66666667, -0.63333333, -0.6       , -0.56666667, -0.53333333,
#         -0.5       , -0.46666667, -0.43333333, -0.4       , -0.36666667,
#         -0.33333333, -0.3       , -0.26666667, -0.23333333, -0.2       ,
#         -0.16666667, -0.13333333, -0.1       , -0.06666667, -0.03333333,
#          0.        ,  0.03333333,  0.06666667,  0.1       ,  0.13333333,
#          0.16666667,  0.2       ,  0.23333333,  0.26666667,  0.3       ,
#          0.33333333,  0.36666667,  0.4       ,  0.43333333,  0.46666667,
#          0.5       ,  0.53333333,  0.56666667,  0.6       ,  0.63333333,
#          0.66666667,  0.7       ,  0.73333333,  0.76666667,  0.8       ,
#          0.83333333,  0.86666667,  0.9       ,  0.93333333,  0.96666667,
#          1.        ,  1.03333333,  1.06666667,  1.1       ,  1.13333333,
#          1.16666667,  1.2       ,  1.23333333,  1.26666667,  1.3       ,
#          1.33333333,  1.36666667,  1.4       ,  1.43333333,  1.46666667,
#          1.5       ,  1.53333333,  1.56666667,  1.6       ,  1.63333333,
#          1.66666667,  1.7       ,  1.73333333,  1.76666667,  1.8       ,
#          1.83333333,  1.86666667,  1.9       ,  1.93333333,  1.96666667,
#          2.        ,  2.03333333,  2.06666667,  2.1       ,  2.13333333,
#          2.16666667,  2.2       ,  2.23333333,  2.26666667,  2.3       ,
#          2.33333333,  2.36666667,  2.4       ,  2.43333333,  2.46666667,
#          2.5       ,  2.53333333,  2.56666667,  2.6       ,  2.63333333,
#          2.66666667,  2.7       ,  2.73333333,  2.76666667,  2.8       ,
#          2.83333333,  2.86666667,  2.9       ,  2.93333333,  2.96666667,
#          3.        ,  3.03333333,  3.06666667,  3.1       ,  3.13333333,
#          3.16666667,  3.2       ,  3.23333333,  3.26666667,  3.3       ,
#          3.33333333,  3.36666667,  3.4       ,  3.43333333,  3.46666667,
#          3.5       ,  3.53333333,  3.56666667,  3.6       ,  3.63333333,
#          3.66666667,  3.7       ,  3.73333333,  3.76666667,  3.8       ,
#          3.83333333,  3.86666667,  3.9       ,  3.93333333,  3.96666667,
#          4.        ,  4.03333333,  4.06666667,  4.1       ,  4.13333333,
#          4.16666667,  4.2       ,  4.23333333,  4.26666667,  4.3       ,
#          4.33333333,  4.36666667,  4.4       ,  4.43333333,  4.46666667,
#          4.5       ,  4.53333333,  4.56666667,  4.6       ,  4.63333333,
#          4.66666667,  4.7       ,  4.73333333,  4.76666667,  4.8       ,
#          4.83333333,  4.86666667,  4.9       ,  4.93333333,  4.96666667,
#          5.        ,  5.03333333,  5.06666667,  5.1       ,  5.13333333,
#          5.16666667,  5.2       ,  5.23333333,  5.26666667,  5.3       ,
#          5.33333333,  5.36666667,  5.4       ,  5.43333333,  5.46666667,
#          5.5       ,  5.53333333,  5.56666667,  5.6       ,  5.63333333,
#          5.66666667,  5.7       ,  5.73333333,  5.76666667,  5.8       ,
#          5.83333333,  5.86666667,  5.9       ,  5.93333333,  5.96666667,
#          6.        ,  6.03333333,  6.06666667,  6.1       ,  6.13333333,
#          6.16666667,  6.2       ,  6.23333333,  6.26666667,  6.3       ,
#          6.33333333,  6.36666667,  6.4       ,  6.43333333,  6.46666667,
#          6.5       ,  6.53333333,  6.56666667,  6.6       ,  6.63333333,
#          6.66666667,  6.7       ,  6.73333333,  6.76666667,  6.8       ,
#          6.83333333,  6.86666667,  6.9       ,  6.93333333,  6.96666667,
#          7.        ,  7.03333333,  7.06666667,  7.1       ,  7.13333333,
#          7.16666667,  7.2       ,  7.23333333,  7.26666667,  7.3       ,
#          7.33333333,  7.36666667,  7.4       ,  7.43333333,  7.46666667,
#          7.5       ,  7.53333333,  7.56666667,  7.6       ,  7.63333333,
#          7.66666667,  7.7       ,  7.73333333,  7.76666667,  7.8       ,
#          7.83333333,  7.86666667,  7.9       ,  7.93333333,  7.96666667,
#          8.        ,  8.03333333,  8.06666667,  8.1       ,  8.13333333,
#          8.16666667,  8.2       ,  8.23333333,  8.26666667,  8.3       ,
#          8.33333333,  8.36666667,  8.4       ,  8.43333333,  8.46666667,
#          8.5       ,  8.53333333,  8.56666667,  8.6       ,  8.63333333,
#          8.66666667,  8.7       ,  8.73333333,  8.76666667,  8.8       ,
#          8.83333333,  8.86666667,  8.9       ,  8.93333333,  8.96666667,
#          9.        ,  9.03333333,  9.06666667,  9.1       ,  9.13333333,
#          9.16666667,  9.2       ,  9.23333333,  9.26666667,  9.3       ,
#          9.33333333,  9.36666667,  9.4       ,  9.43333333,  9.46666667,
#          9.5       ,  9.53333333,  9.56666667,  9.6       ,  9.63333333,
#          9.66666667,  9.7       ,  9.73333333,  9.76666667,  9.8       ,
#          9.83333333,  9.86666667,  9.9       ,  9.93333333,  9.96666667,
#         10.        , 10.03333333, 10.06666667, 10.1       , 10.13333333,
#         10.16666667, 10.2       , 10.23333333, 10.26666667, 10.3       ,
#         10.33333333, 10.36666667, 10.4       , 10.43333333, 10.46666667,
#         10.5       , 10.53333333, 10.56666667, 10.6       , 10.63333333,
#         10.66666667, 10.7       , 10.73333333, 10.76666667, 10.8       ,
#         10.83333333, 10.86666667, 10.9       , 10.93333333, 10.96666667,
#         11.        , 11.03333333, 11.06666667, 11.1       , 11.13333333,
#         11.16666667, 11.2       , 11.23333333, 11.26666667, 11.3       ,
#         11.33333333, 11.36666667, 11.4       , 11.43333333, 11.46666667,
#         11.5       , 11.53333333, 11.56666667, 11.6       , 11.63333333,
#         11.66666667, 11.7       , 11.73333333, 11.76666667, 11.8       ,
#         11.83333333, 11.86666667, 11.9       , 11.93333333, 11.96666667,
#         12.        , 12.03333333, 12.06666667, 12.1       , 12.13333333,
#         12.16666667, 12.2       , 12.23333333, 12.26666667, 12.3       ,
#         12.33333333, 12.36666667, 12.4       , 12.43333333, 12.46666667,
#         12.5       , 12.53333333, 12.56666667, 12.6       , 12.63333333,
#         12.66666667, 12.7       , 12.73333333, 12.76666667, 12.8       ,
#         12.83333333, 12.86666667, 12.9       , 12.93333333, 12.96666667,
#         13.        , 13.03333333, 13.06666667, 13.1       , 13.13333333,
#         13.16666667, 13.2       , 13.23333333, 13.26666667, 13.3       ,
#         13.33333333, 13.36666667, 13.4       , 13.43333333, 13.46666667,
#         13.5       , 13.53333333, 13.56666667, 13.6       , 13.63333333,
#         13.66666667, 13.7       , 13.73333333, 13.76666667, 13.8       ,
#         13.83333333, 13.86666667, 13.9       , 13.93333333, 13.96666667,
#         14.        , 14.03333333, 14.06666667, 14.1       , 14.13333333,
#         14.16666667, 14.2       , 14.23333333, 14.26666667, 14.3       ,
#         14.33333333, 14.36666667, 14.4       , 14.43333333, 14.46666667,
#         14.5       , 14.53333333, 14.56666667, 14.6       , 14.63333333,
#         14.66666667, 14.7       , 14.73333333, 14.76666667, 14.8       ,
#         14.83333333, 14.86666667, 14.9       , 14.93333333, 14.96666667,
#         15.        , 15.03333333, 15.06666667, 15.1       , 15.13333333,
#         15.16666667, 15.2       , 15.23333333, 15.26666667, 15.3       ,
#         15.33333333, 15.36666667, 15.4       , 15.43333333, 15.46666667,
#         15.5       , 15.53333333, 15.56666667, 15.6       , 15.63333333,
#         15.66666667, 15.7       , 15.73333333, 15.76666667, 15.8       ,
#         15.83333333, 15.86666667, 15.9       , 15.93333333, 15.96666667,
#         16.        ]),
#  <a list of 510 Patch objects>)

# %%
sum(length_score)/len(length_score)
# Another comparation for the norm level
# Out:
# 0.6150432040982255
